# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -d ./dataverse_files /content/drive/MyDrive/dataverse_files.zip

# !unzip -d ./dataverse_files/HAM10000_images_part_1 /content/dataverse_files/HAM10000_images_part_1.zip
# !unzip -d ./dataverse_files/HAM10000_images_part_2 /content/dataverse_files/HAM10000_images_part_2.zip
# !unzip -d ./dataverse_files /content/dataverse_files/ISIC2018_Task3_Test_Images.zip

# %% [markdown]
# # 1. Preprocessing

# %%
import pandas as pd
import os
import shutil

# %%
# move training and test images into folders

# create train and test folder
if not os.path.exists('dataverse_files/train'):
    os.mkdir('dataverse_files/train')
    
if not os.path.exists('dataverse_files/test'):
    os.mkdir('dataverse_files/test')
    
for img_name in os.listdir('dataverse_files/HAM10000_images_part_1/'):
    src_path = os.path.join('dataverse_files/HAM10000_images_part_1', img_name)
    tgt_path = 'dataverse_files/train'
    shutil.move(src_path, tgt_path)
    
for img_name in os.listdir('dataverse_files/HAM10000_images_part_2/'):
    src_path = os.path.join('dataverse_files/HAM10000_images_part_2', img_name)
    tgt_path = 'dataverse_files/train'
    shutil.move(src_path, tgt_path)

for img_name in os.listdir('dataverse_files/ISIC2018_Task3_Test_Images/'):
    src_path = os.path.join('dataverse_files/ISIC2018_Task3_Test_Images', img_name)
    tgt_path = 'dataverse_files/test'
    shutil.move(src_path, tgt_path)

# %%
train_df = pd.read_csv('dataverse_files/HAM10000_metadata')
test_df = pd.read_csv('dataverse_files/ISIC2018_Task3_Test_NatureMedicine_AI_Interaction_Benefit.csv')

# %%
# convert to numerical representation
from sklearn.preprocessing import LabelEncoder

lb = LabelEncoder()
lb.fit_transform(train_df['dx'])
cls2lbl = {cls: idx for idx, cls in enumerate(lb.classes_)}
lbl2cls = {idx: cls for idx, cls in enumerate(lb.classes_)}
train_df['label'] = [cls2lbl[cls] for cls in train_df['dx']]

# %%
# extract label in test set
test_df['label'] = test_df[['prob_h_dx_akiec', 
                            'prob_h_dx_bcc',
                            'prob_h_dx_bkl', 
                            'prob_h_dx_df', 
                            'prob_h_dx_mel', 
                            'prob_h_dx_nv',
                            'prob_h_dx_vasc']].values.argmax(axis=1)

# %% [markdown]
# # 2. Data loader

# %%
from PIL import Image
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import ToTensor, RandomAffine, Resize, CenterCrop, Normalize

class MyDataset(Dataset):
    def __init__(self, train=True):
        self.meta = train_df if train else test_df
        self.root_dir = 'dataverse_files/train' if train else 'dataverse_files/test'
    def __len__(self):
        return len(self.meta)
    def __getitem__(self, idx):
        img_name = self.meta['image_id'].iloc[idx] + '.jpg'
        img_path = os.path.join(self.root_dir, img_name)

        image = Image.open(img_path)
        image = Resize((224, 224))(image)
        image = CenterCrop(224)(image)
        image = RandomAffine(degrees=(-10, 10), translate=(0.05, 0.1), scale=(0.9, 1.1))(image)
        image = ToTensor()(image)
        image = Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])(image)
        
        label = self.meta['label'].iloc[idx]
        return image, label

train_dataset = MyDataset(train=True)
test_dataset = MyDataset(train=False)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=100, shuffle=False)

# %% [markdown]
# # 3. Models

# %%
import torch.nn as nn
from torchvision.models import resnet18

model = resnet18()
model.fc = nn.Linear(in_features=512, out_features=len(lbl2cls))
model
# Out:
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=7, bias=True)
# )

# %% [markdown]
# # 4. Train

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

n_epochs = 10
lr = 0.001
optimizer = torch.optim.Adam(params=model.parameters(), lr=lr)
loss_func = torch.nn.CrossEntropyLoss()
best_test_acc = 0

for i in range(n_epochs):
    for idx, (image, label) in enumerate(train_loader):
        image = image.to(device)
        label = label.to(device)
        
        y_pred = model(image)
        loss = loss_func(y_pred, label)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if (idx + 1) % 10 == 0:
            print(f'Iteration: {i+1}/{n_epochs}, Step: {idx+1}/{len(train_loader)}, Loss: {loss.item():.4f}')
    
    model.eval()
    with torch.no_grad():
        n_instances = len(test_loader)
        n_correct = 0
        for image, label in test_loader:
            image = image.to(device)
            label = label.to(device)
            
            y_pred = model(image)
            pred = torch.argmax(y_pred, dim=1)
            n_correct += (pred == label).sum().item()
        test_acc = n_correct / n_instances
        print(f'Iteration: {i+1}/{n_epochs}, Test accuracy: {test_acc:.4f}')
        
        if test_acc > best_test_acc:
            best_test_acc = test_acc
            torch.save(model, 'best_model.pth')
        
    model.train()
    
print(f'Best test accuracy: {best_test_acc:.4f}')
# Out:
# Iteration: 1/10, Step: 10/313, Loss: 1.4733
# Iteration: 1/10, Step: 20/313, Loss: 1.1430
# Iteration: 1/10, Step: 30/313, Loss: 0.9174
# Iteration: 1/10, Step: 40/313, Loss: 0.9154
# Iteration: 1/10, Step: 50/313, Loss: 0.7123
# Iteration: 1/10, Step: 60/313, Loss: 1.1752
# Iteration: 1/10, Step: 70/313, Loss: 1.0660
# Iteration: 1/10, Step: 80/313, Loss: 0.7440
# Iteration: 1/10, Step: 90/313, Loss: 0.7250
# Iteration: 1/10, Step: 100/313, Loss: 1.1006
# Iteration: 1/10, Step: 110/313, Loss: 0.8034
# Iteration: 1/10, Step: 120/313, Loss: 1.0822
# Iteration: 1/10, Step: 130/313, Loss: 1.2607
# Iteration: 1/10, Step: 140/313, Loss: 0.9362
# Iteration: 1/10, Step: 150/313, Loss: 0.9111
# Iteration: 1/10, Step: 160/313, Loss: 0.8648
# Iteration: 1/10, Step: 170/313, Loss: 1.1544
# Iteration: 1/10, Step: 180/313, Loss: 0.9275
# Iteration: 1/10, Step: 190/313, Loss: 0.7070
# Iteration: 1/10, Step: 200/313, Loss: 0.6877
# Iteration: 1/10, Step: 210/313, Loss: 0.8753
# Iteration: 1/10, Step: 220/313, Loss: 0.7197
# Iteration: 1/10, Step: 230/313, Loss: 0.7027
# Iteration: 1/10, Step: 240/313, Loss: 1.0735
# Iteration: 1/10, Step: 250/313, Loss: 1.0555
# Iteration: 1/10, Step: 260/313, Loss: 1.2868
# Iteration: 1/10, Step: 270/313, Loss: 1.2881
# Iteration: 1/10, Step: 280/313, Loss: 0.9898
# Iteration: 1/10, Step: 290/313, Loss: 1.1543
# Iteration: 1/10, Step: 300/313, Loss: 0.7351
# Iteration: 1/10, Step: 310/313, Loss: 0.5412
# Iteration: 1/10, Test accuracy: 44.0789
# Iteration: 2/10, Step: 10/313, Loss: 0.7144
# Iteration: 2/10, Step: 20/313, Loss: 0.6710
# Iteration: 2/10, Step: 30/313, Loss: 0.9148
# Iteration: 2/10, Step: 40/313, Loss: 1.0814
# Iteration: 2/10, Step: 50/313, Loss: 0.7848
# Iteration: 2/10, Step: 60/313, Loss: 1.0029
# Iteration: 2/10, Step: 70/313, Loss: 1.1417
# Iteration: 2/10, Step: 80/313, Loss: 1.0432
# Iteration: 2/10, Step: 90/313, Loss: 0.4993
# Iteration: 2/10, Step: 100/313, Loss: 0.8021
# Iteration: 2/10, Step: 110/313, Loss: 0.8334
# Iteration: 2/10, Step: 120/313, Loss: 1.0048
# Iteration: 2/10, Step: 130/313, Loss: 0.9525
# Iteration: 2/10, Step: 140/313, Loss: 0.8098
# Iteration: 2/10, Step: 150/313, Loss: 1.4563
# Iteration: 2/10, Step: 160/313, Loss: 0.8264
# Iteration: 2/10, Step: 170/313, Loss: 1.1145
# Iteration: 2/10, Step: 180/313, Loss: 0.8150
# Iteration: 2/10, Step: 190/313, Loss: 0.7561
# Iteration: 2/10, Step: 200/313, Loss: 0.7448
# Iteration: 2/10, Step: 210/313, Loss: 1.0043
# Iteration: 2/10, Step: 220/313, Loss: 0.9842
# Iteration: 2/10, Step: 230/313, Loss: 0.9561
# Iteration: 2/10, Step: 240/313, Loss: 0.6851
# Iteration: 2/10, Step: 250/313, Loss: 1.5074
# Iteration: 2/10, Step: 260/313, Loss: 0.8465
# Iteration: 2/10, Step: 270/313, Loss: 1.0343
# Iteration: 2/10, Step: 280/313, Loss: 0.7458
# Iteration: 2/10, Step: 290/313, Loss: 0.5023
# Iteration: 2/10, Step: 300/313, Loss: 0.8557
# Iteration: 2/10, Step: 310/313, Loss: 0.6717
# Iteration: 2/10, Test accuracy: 48.9474
# Iteration: 3/10, Step: 10/313, Loss: 0.8234
# Iteration: 3/10, Step: 20/313, Loss: 0.6309
# Iteration: 3/10, Step: 30/313, Loss: 0.6988
# Iteration: 3/10, Step: 40/313, Loss: 1.0672
# Iteration: 3/10, Step: 50/313, Loss: 0.6741
# Iteration: 3/10, Step: 60/313, Loss: 0.5174
# Iteration: 3/10, Step: 70/313, Loss: 0.6205
# Iteration: 3/10, Step: 80/313, Loss: 0.7235
# Iteration: 3/10, Step: 90/313, Loss: 0.6573
# Iteration: 3/10, Step: 100/313, Loss: 0.7509
# Iteration: 3/10, Step: 110/313, Loss: 0.6640
# Iteration: 3/10, Step: 120/313, Loss: 0.8117
# Iteration: 3/10, Step: 130/313, Loss: 0.7283
# Iteration: 3/10, Step: 140/313, Loss: 0.6225
# Iteration: 3/10, Step: 150/313, Loss: 1.1780
# Iteration: 3/10, Step: 160/313, Loss: 0.8824
# Iteration: 3/10, Step: 170/313, Loss: 0.8291
# Iteration: 3/10, Step: 180/313, Loss: 0.8783
# Iteration: 3/10, Step: 190/313, Loss: 0.8528
# Iteration: 3/10, Step: 200/313, Loss: 0.8113
# Iteration: 3/10, Step: 210/313, Loss: 1.1184
# Iteration: 3/10, Step: 220/313, Loss: 0.8525
# Iteration: 3/10, Step: 230/313, Loss: 0.8577
# Iteration: 3/10, Step: 240/313, Loss: 0.8442
# Iteration: 3/10, Step: 250/313, Loss: 0.9037
# Iteration: 3/10, Step: 260/313, Loss: 1.0862
# Iteration: 3/10, Step: 270/313, Loss: 0.5873
# Iteration: 3/10, Step: 280/313, Loss: 0.6385
# Iteration: 3/10, Step: 290/313, Loss: 1.2410
# Iteration: 3/10, Step: 300/313, Loss: 0.6460
# Iteration: 3/10, Step: 310/313, Loss: 0.6330
# Iteration: 3/10, Test accuracy: 46.2632
# Iteration: 4/10, Step: 10/313, Loss: 1.0337
# Iteration: 4/10, Step: 20/313, Loss: 0.9567
# Iteration: 4/10, Step: 30/313, Loss: 1.0088
# Iteration: 4/10, Step: 40/313, Loss: 0.6501
# Iteration: 4/10, Step: 50/313, Loss: 0.5019
# Iteration: 4/10, Step: 60/313, Loss: 0.5683
# Iteration: 4/10, Step: 70/313, Loss: 0.4371
# Iteration: 4/10, Step: 80/313, Loss: 0.9142
# Iteration: 4/10, Step: 90/313, Loss: 0.4932
# Iteration: 4/10, Step: 100/313, Loss: 0.6759
# Iteration: 4/10, Step: 110/313, Loss: 0.7393
# Iteration: 4/10, Step: 120/313, Loss: 0.6165
# Iteration: 4/10, Step: 130/313, Loss: 0.9311
# Iteration: 4/10, Step: 140/313, Loss: 0.8428
# Iteration: 4/10, Step: 150/313, Loss: 0.8788
# Iteration: 4/10, Step: 160/313, Loss: 0.9201
# Iteration: 4/10, Step: 170/313, Loss: 0.7167
# Iteration: 4/10, Step: 180/313, Loss: 0.8108
# Iteration: 4/10, Step: 190/313, Loss: 0.7043
# Iteration: 4/10, Step: 200/313, Loss: 1.0850
# Iteration: 4/10, Step: 210/313, Loss: 0.7657
# Iteration: 4/10, Step: 220/313, Loss: 0.6609
# Iteration: 4/10, Step: 230/313, Loss: 1.3972
# Iteration: 4/10, Step: 240/313, Loss: 0.6667
# Iteration: 4/10, Step: 250/313, Loss: 0.4790
# Iteration: 4/10, Step: 260/313, Loss: 0.8465
# Iteration: 4/10, Step: 270/313, Loss: 0.6066
# Iteration: 4/10, Step: 280/313, Loss: 0.8643
# Iteration: 4/10, Step: 290/313, Loss: 0.8452
# Iteration: 4/10, Step: 300/313, Loss: 0.7351
# Iteration: 4/10, Step: 310/313, Loss: 0.6327
# Iteration: 4/10, Test accuracy: 47.6316
# Iteration: 5/10, Step: 10/313, Loss: 0.8658
# Iteration: 5/10, Step: 20/313, Loss: 0.8948
# Iteration: 5/10, Step: 30/313, Loss: 0.6486
# Iteration: 5/10, Step: 40/313, Loss: 1.2226
# Iteration: 5/10, Step: 50/313, Loss: 0.9027
# Iteration: 5/10, Step: 60/313, Loss: 1.0040
# Iteration: 5/10, Step: 70/313, Loss: 0.9229
# Iteration: 5/10, Step: 80/313, Loss: 0.7652
# Iteration: 5/10, Step: 90/313, Loss: 0.8959
# Iteration: 5/10, Step: 100/313, Loss: 0.8338
# Iteration: 5/10, Step: 110/313, Loss: 0.7273
# Iteration: 5/10, Step: 120/313, Loss: 0.6260
# Iteration: 5/10, Step: 130/313, Loss: 0.8678
# Iteration: 5/10, Step: 140/313, Loss: 0.8382
# Iteration: 5/10, Step: 150/313, Loss: 0.5393
# Iteration: 5/10, Step: 160/313, Loss: 0.4798
# Iteration: 5/10, Step: 170/313, Loss: 0.8287
# Iteration: 5/10, Step: 180/313, Loss: 0.7733
# Iteration: 5/10, Step: 190/313, Loss: 0.6620
# Iteration: 5/10, Step: 200/313, Loss: 0.8290
# Iteration: 5/10, Step: 210/313, Loss: 0.9678
# Iteration: 5/10, Step: 220/313, Loss: 0.7425
# Iteration: 5/10, Step: 230/313, Loss: 0.6487
# Iteration: 5/10, Step: 240/313, Loss: 0.6887
# Iteration: 5/10, Step: 250/313, Loss: 0.5149
# Iteration: 5/10, Step: 260/313, Loss: 0.6405
# Iteration: 5/10, Step: 270/313, Loss: 0.9228
# Iteration: 5/10, Step: 280/313, Loss: 0.6719
# Iteration: 5/10, Step: 290/313, Loss: 0.8646
# Iteration: 5/10, Step: 300/313, Loss: 0.7649
# Iteration: 5/10, Step: 310/313, Loss: 0.9808
# Iteration: 5/10, Test accuracy: 44.3421
# Iteration: 6/10, Step: 10/313, Loss: 0.8356
# Iteration: 6/10, Step: 20/313, Loss: 0.5307
# Iteration: 6/10, Step: 30/313, Loss: 0.6801
# Iteration: 6/10, Step: 40/313, Loss: 0.6279
# Iteration: 6/10, Step: 50/313, Loss: 0.7345
# Iteration: 6/10, Step: 60/313, Loss: 0.5762
# Iteration: 6/10, Step: 70/313, Loss: 0.7918
# Iteration: 6/10, Step: 80/313, Loss: 0.6495
# Iteration: 6/10, Step: 90/313, Loss: 1.0405
# Iteration: 6/10, Step: 100/313, Loss: 0.8209
# Iteration: 6/10, Step: 110/313, Loss: 1.1540
# Iteration: 6/10, Step: 120/313, Loss: 0.5476
# Iteration: 6/10, Step: 130/313, Loss: 1.1761
# Iteration: 6/10, Step: 140/313, Loss: 0.8816
# Iteration: 6/10, Step: 150/313, Loss: 1.1252
# Iteration: 6/10, Step: 160/313, Loss: 0.6543
# Iteration: 6/10, Step: 170/313, Loss: 0.6552
# Iteration: 6/10, Step: 180/313, Loss: 0.6480
# Iteration: 6/10, Step: 190/313, Loss: 0.8163
# Iteration: 6/10, Step: 200/313, Loss: 0.7488
# Iteration: 6/10, Step: 210/313, Loss: 0.4699
# Iteration: 6/10, Step: 220/313, Loss: 0.5191
# Iteration: 6/10, Step: 230/313, Loss: 0.6654
# Iteration: 6/10, Step: 240/313, Loss: 0.5218
# Iteration: 6/10, Step: 250/313, Loss: 0.8532
# Iteration: 6/10, Step: 260/313, Loss: 0.6781
# Iteration: 6/10, Step: 270/313, Loss: 0.6158
# Iteration: 6/10, Step: 280/313, Loss: 0.8166
# Iteration: 6/10, Step: 290/313, Loss: 0.6558
# Iteration: 6/10, Step: 300/313, Loss: 0.7258
# Iteration: 6/10, Step: 310/313, Loss: 0.5573
# Iteration: 6/10, Test accuracy: 51.4211
# Iteration: 7/10, Step: 10/313, Loss: 0.6596
# Iteration: 7/10, Step: 20/313, Loss: 0.7122
# Iteration: 7/10, Step: 30/313, Loss: 0.5929
# Iteration: 7/10, Step: 40/313, Loss: 0.8237
# Iteration: 7/10, Step: 50/313, Loss: 0.6686
# Iteration: 7/10, Step: 60/313, Loss: 0.6803
# Iteration: 7/10, Step: 70/313, Loss: 0.7061
# Iteration: 7/10, Step: 80/313, Loss: 0.7196
# Iteration: 7/10, Step: 90/313, Loss: 0.7548
# Iteration: 7/10, Step: 100/313, Loss: 0.9226
# Iteration: 7/10, Step: 110/313, Loss: 0.6611
# Iteration: 7/10, Step: 120/313, Loss: 1.0688
# Iteration: 7/10, Step: 130/313, Loss: 0.7363
# Iteration: 7/10, Step: 140/313, Loss: 0.7206
# Iteration: 7/10, Step: 150/313, Loss: 0.4953
# Iteration: 7/10, Step: 160/313, Loss: 0.6519
# Iteration: 7/10, Step: 170/313, Loss: 0.6076
# Iteration: 7/10, Step: 180/313, Loss: 0.7780
# Iteration: 7/10, Step: 190/313, Loss: 0.4402
# Iteration: 7/10, Step: 200/313, Loss: 0.6131
# Iteration: 7/10, Step: 210/313, Loss: 0.5989
# Iteration: 7/10, Step: 220/313, Loss: 0.7012
# Iteration: 7/10, Step: 230/313, Loss: 0.6975
# Iteration: 7/10, Step: 240/313, Loss: 1.0611
# Iteration: 7/10, Step: 250/313, Loss: 0.6522
# Iteration: 7/10, Step: 260/313, Loss: 0.4722
# Iteration: 7/10, Step: 270/313, Loss: 0.5464
# Iteration: 7/10, Step: 280/313, Loss: 0.6867
# Iteration: 7/10, Step: 290/313, Loss: 1.2469
# Iteration: 7/10, Step: 300/313, Loss: 0.7015
# Iteration: 7/10, Step: 310/313, Loss: 0.6350
# Iteration: 7/10, Test accuracy: 51.1842
# Iteration: 8/10, Step: 10/313, Loss: 0.6854
# Iteration: 8/10, Step: 20/313, Loss: 0.6361
# Iteration: 8/10, Step: 30/313, Loss: 1.2153
# Iteration: 8/10, Step: 40/313, Loss: 0.6389
# Iteration: 8/10, Step: 50/313, Loss: 0.6135
# Iteration: 8/10, Step: 60/313, Loss: 0.6497
# Iteration: 8/10, Step: 70/313, Loss: 0.3679
# Iteration: 8/10, Step: 80/313, Loss: 0.7129
# Iteration: 8/10, Step: 90/313, Loss: 0.6399
# Iteration: 8/10, Step: 100/313, Loss: 1.1019
# Iteration: 8/10, Step: 110/313, Loss: 0.7905
# Iteration: 8/10, Step: 120/313, Loss: 0.3711
# Iteration: 8/10, Step: 130/313, Loss: 0.8720
# Iteration: 8/10, Step: 140/313, Loss: 0.5680
# Iteration: 8/10, Step: 150/313, Loss: 0.5365
# Iteration: 8/10, Step: 160/313, Loss: 0.5308
# Iteration: 8/10, Step: 170/313, Loss: 0.5160
# Iteration: 8/10, Step: 180/313, Loss: 0.5258
# Iteration: 8/10, Step: 190/313, Loss: 0.3953
# Iteration: 8/10, Step: 200/313, Loss: 1.1403
# Iteration: 8/10, Step: 210/313, Loss: 0.7316
# Iteration: 8/10, Step: 220/313, Loss: 0.9509
# Iteration: 8/10, Step: 230/313, Loss: 0.5222
# Iteration: 8/10, Step: 240/313, Loss: 0.6348
# Iteration: 8/10, Step: 250/313, Loss: 0.5220
# Iteration: 8/10, Step: 260/313, Loss: 0.7861
# Iteration: 8/10, Step: 270/313, Loss: 0.7877
# Iteration: 8/10, Step: 280/313, Loss: 0.6059
# Iteration: 8/10, Step: 290/313, Loss: 0.6776
# Iteration: 8/10, Step: 300/313, Loss: 0.7043
# Iteration: 8/10, Step: 310/313, Loss: 0.8869
# Iteration: 8/10, Test accuracy: 52.6316
# Iteration: 9/10, Step: 10/313, Loss: 0.5854
# Iteration: 9/10, Step: 20/313, Loss: 0.8811
# Iteration: 9/10, Step: 30/313, Loss: 0.4946
# Iteration: 9/10, Step: 40/313, Loss: 0.7943
# Iteration: 9/10, Step: 50/313, Loss: 0.7468
# Iteration: 9/10, Step: 60/313, Loss: 0.4585
# Iteration: 9/10, Step: 70/313, Loss: 0.6212
# Iteration: 9/10, Step: 80/313, Loss: 0.7745
# Iteration: 9/10, Step: 90/313, Loss: 0.5864
# Iteration: 9/10, Step: 100/313, Loss: 0.8423
# Iteration: 9/10, Step: 110/313, Loss: 0.8805
# Iteration: 9/10, Step: 120/313, Loss: 0.4829
# Iteration: 9/10, Step: 130/313, Loss: 0.4914
# Iteration: 9/10, Step: 140/313, Loss: 0.5928
# Iteration: 9/10, Step: 150/313, Loss: 0.6522
# Iteration: 9/10, Step: 160/313, Loss: 0.4758
# Iteration: 9/10, Step: 170/313, Loss: 0.4192
# Iteration: 9/10, Step: 180/313, Loss: 0.8828
# Iteration: 9/10, Step: 190/313, Loss: 0.6790
# Iteration: 9/10, Step: 200/313, Loss: 0.5178
# Iteration: 9/10, Step: 210/313, Loss: 0.7578
# Iteration: 9/10, Step: 220/313, Loss: 0.5286
# Iteration: 9/10, Step: 230/313, Loss: 0.8036
# Iteration: 9/10, Step: 240/313, Loss: 0.8080
# Iteration: 9/10, Step: 250/313, Loss: 0.8247
# Iteration: 9/10, Step: 260/313, Loss: 0.5703
# Iteration: 9/10, Step: 270/313, Loss: 0.9894
# Iteration: 9/10, Step: 280/313, Loss: 0.6961
# Iteration: 9/10, Step: 290/313, Loss: 0.6512
# Iteration: 9/10, Step: 300/313, Loss: 0.4509
# Iteration: 9/10, Step: 310/313, Loss: 0.8308
# Iteration: 9/10, Test accuracy: 53.9474
# Iteration: 10/10, Step: 10/313, Loss: 0.6650
# Iteration: 10/10, Step: 20/313, Loss: 0.6671
# Iteration: 10/10, Step: 30/313, Loss: 0.6202
# Iteration: 10/10, Step: 40/313, Loss: 0.5698
# Iteration: 10/10, Step: 50/313, Loss: 0.5859
# Iteration: 10/10, Step: 60/313, Loss: 0.6164
# Iteration: 10/10, Step: 70/313, Loss: 0.5642
# Iteration: 10/10, Step: 80/313, Loss: 0.8500
# Iteration: 10/10, Step: 90/313, Loss: 1.0539
# Iteration: 10/10, Step: 100/313, Loss: 1.0211
# Iteration: 10/10, Step: 110/313, Loss: 0.8337
# Iteration: 10/10, Step: 120/313, Loss: 0.8508
# Iteration: 10/10, Step: 130/313, Loss: 0.6567
# Iteration: 10/10, Step: 140/313, Loss: 0.9004
# Iteration: 10/10, Step: 150/313, Loss: 0.8000
# Iteration: 10/10, Step: 160/313, Loss: 0.6521
# Iteration: 10/10, Step: 170/313, Loss: 0.4541
# Iteration: 10/10, Step: 180/313, Loss: 0.6398
# Iteration: 10/10, Step: 190/313, Loss: 0.9407
# Iteration: 10/10, Step: 200/313, Loss: 0.4208
# Iteration: 10/10, Step: 210/313, Loss: 0.8223
# Iteration: 10/10, Step: 220/313, Loss: 0.7082
# Iteration: 10/10, Step: 230/313, Loss: 0.7405
# Iteration: 10/10, Step: 240/313, Loss: 0.7154
# Iteration: 10/10, Step: 250/313, Loss: 0.5195
# Iteration: 10/10, Step: 260/313, Loss: 0.8445
# Iteration: 10/10, Step: 270/313, Loss: 0.5642
# Iteration: 10/10, Step: 280/313, Loss: 0.6490
# Iteration: 10/10, Step: 290/313, Loss: 0.6304
# Iteration: 10/10, Step: 300/313, Loss: 1.0348
# Iteration: 10/10, Step: 310/313, Loss: 0.8213
# Iteration: 10/10, Test accuracy: 55.7632
# Best test accuracy: 55.7632

# %%
# !cp /content/best_model.pth /content/drive/MyDrive

# %% [markdown]
# # 5. Evaluate

# %%
best_model = torch.load('best_model.pth')
best_model.eval()
with torch.no_grad():
    y_preds = []
    y_trues = []
    for image, label in test_loader:
        image = image.to(device)
        label = label.to(device)
        
        y_pred = model(image)
        pred = torch.argmax(y_pred, dim=1)

        y_trues.append(label.cpu().numpy())
        y_preds.append(pred.cpu().numpy())

# %%
import numpy as np
from sklearn.metrics import recall_score

y_preds = np.concatenate(y_preds)
y_trues = np.concatenate(y_trues)

scores = recall_score(y_trues, y_preds, average=None)
scores
# Out:
# array([0.21875   , 0.48324022, 0.30205656, 0.        , 0.27906977,
#        0.93622985, 0.38607595])
