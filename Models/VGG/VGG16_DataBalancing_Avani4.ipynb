# %%
#import statements
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from glob import glob
from tqdm._tqdm_notebook import tqdm_notebook as tqdm
import seaborn as sns
from PIL import Image
import tensorflow as tf
from google.colab import drive
from sklearn.metrics import confusion_matrix
import keras
from keras.utils.np_utils import to_categorical 
from keras.models import Model
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, Activation, GlobalAveragePooling2D, ZeroPadding2D
from keras.applications import vgg16
from sklearn.model_selection import train_test_split
from scipy import stats
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import resample
from tensorflow.keras.models import Model
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.*` instead of `tqdm._tqdm_notebook.*`
#   import sys

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! unzip '/content/drive/MyDrive/HAM10000_metadata_gc.zip'
# Out:
# Archive:  /content/drive/MyDrive/HAM10000_metadata_gc.zip
#   inflating: HAM10000_metadata

# %%
! unzip '/content/drive/MyDrive/HAM10000_images_part_1_gc'

# %%
! unzip '/content/drive/MyDrive/HAM10000_images_part_2_gc'

# %%
md = pd.read_csv("/content/HAM10000_metadata")
md

# %%
#vgg16 model accepts images of 224X224X3
im_size = 224

# %%
#set aside a portion of full dataset for testing
dxs = md["dx"].unique()

ldxs = {}

for dx, group in md.groupby("dx"):
    ldxs[dx] = []
    images = list(group["image_id"])
    np.random.shuffle(images)
    for i in range(75):
        ldxs[dx].append(images[i])

# %%
ts = pd.DataFrame.from_dict(ldxs, orient='index')
ts = ts.T
ts

# %%
t_akiec_imid = ts.akiec.values.tolist()
t_akiec_dx = ['akiec'] * 75
ts_aikec = pd.DataFrame(list(zip(t_akiec_imid, t_akiec_dx)), columns=['image_id', 'dx'])

t_bcc_imid = ts.bcc.values.tolist()
t_bcc_dx = ['bcc'] * 75
ts_bcc = pd.DataFrame(list(zip(t_bcc_imid, t_bcc_dx)), columns=['image_id', 'dx'])

t_bkl_imid = ts.bkl.values.tolist()
t_bkl_dx = ['bkl'] * 75
ts_bkl = pd.DataFrame(list(zip(t_bkl_imid, t_bkl_dx)), columns=['image_id', 'dx'])

t_df_imid = ts.df.values.tolist()
t_df_dx = ['df'] * 75
ts_df = pd.DataFrame(list(zip(t_df_imid, t_df_dx)), columns=['image_id', 'dx'])

t_mel_imid = ts.mel.values.tolist()
t_mel_dx = ['mel'] * 75
ts_mel = pd.DataFrame(list(zip(t_mel_imid, t_mel_dx)), columns=['image_id', 'dx'])

t_nv_imid = ts.nv.values.tolist()
t_nv_dx = ['nv'] * 75
ts_nv = pd.DataFrame(list(zip(t_nv_imid, t_nv_dx)), columns=['image_id', 'dx'])

t_vasc_imid = ts.vasc.values.tolist()
t_vasc_dx = ['vasc'] * 75
ts_vasc = pd.DataFrame(list(zip(t_vasc_imid, t_vasc_dx)), columns=['image_id', 'dx'])

ts_balanced = pd.concat([ts_aikec, ts_bcc, ts_bkl, ts_df, ts_mel, ts_nv, ts_vasc])
ts_balanced
# Out:
#         image_id     dx
# 0   ISIC_0033084  akiec
# 1   ISIC_0027178  akiec
# 2   ISIC_0030491  akiec
# 3   ISIC_0028619  akiec
# 4   ISIC_0027529  akiec
# ..           ...    ...
# 70  ISIC_0026876   vasc
# 71  ISIC_0029889   vasc
# 72  ISIC_0027937   vasc
# 73  ISIC_0032867   vasc
# 74  ISIC_0032775   vasc
#
# [525 rows x 2 columns]

# %%
cond = md['image_id'].isin(ts_balanced['image_id'])
trainset = md.drop(md[cond].index)

trainset
# Out:
#          lesion_id      image_id     dx dx_type   age     sex  \
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male
# ...            ...           ...    ...     ...   ...     ...
# 10009  HAM_0005705  ISIC_0031430  akiec   histo  75.0  female
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female
#
#           localization       dataset
# 0                scalp  vidir_modern
# 1                scalp  vidir_modern
# 2                scalp  vidir_modern
# 3                scalp  vidir_modern
# 4                  ear  vidir_modern
# ...                ...           ...
# 10009  lower extremity  vidir_modern
# 10011          abdomen  vidir_modern
# 10012          abdomen  vidir_modern
# 10013             face  vidir_modern
# 10014             back  vidir_modern
#
# [9490 rows x 8 columns]

# %%
#label encoding: going from text to numerical
lab_enc = LabelEncoder()
lab_enc.fit(trainset['dx'])
LabelEncoder()
print(list(lab_enc.classes_))
# Out:
# ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']

# %%
lab_enc = LabelEncoder()
lab_enc.fit(ts_balanced['dx'])
LabelEncoder()
print(list(lab_enc.classes_))
# Out:
# ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']

# %%
#label column in md - diagnosis and numerical label in one dataset
trainset['label'] = lab_enc.transform(trainset["dx"]) 
ts_balanced['label'] = lab_enc.transform(ts_balanced["dx"]) 
trainset
# Out:
#          lesion_id      image_id     dx dx_type   age     sex  \
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male
# ...            ...           ...    ...     ...   ...     ...
# 10009  HAM_0005705  ISIC_0031430  akiec   histo  75.0  female
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female
#
#           localization       dataset  label
# 0                scalp  vidir_modern      2
# 1                scalp  vidir_modern      2
# 2                scalp  vidir_modern      2
# 3                scalp  vidir_modern      2
# 4                  ear  vidir_modern      2
# ...                ...           ...    ...
# 10009  lower extremity  vidir_modern      0
# 10011          abdomen  vidir_modern      0
# 10012          abdomen  vidir_modern      0
# 10013             face  vidir_modern      0
# 10014             back  vidir_modern      4
#
# [9490 rows x 9 columns]

# %%
ts_balanced
# Out:
#         image_id     dx  label
# 0   ISIC_0033084  akiec      0
# 1   ISIC_0027178  akiec      0
# 2   ISIC_0030491  akiec      0
# 3   ISIC_0028619  akiec      0
# 4   ISIC_0027529  akiec      0
# ..           ...    ...    ...
# 70  ISIC_0026876   vasc      6
# 71  ISIC_0029889   vasc      6
# 72  ISIC_0027937   vasc      6
# 73  ISIC_0032867   vasc      6
# 74  ISIC_0032775   vasc      6
#
# [525 rows x 3 columns]

# %%
#get all file paths and make a new column
fldr1 = '/content/HAM10000_images_part_1'
fldr2 = '/content/HAM10000_images_part_2'

im_paths = []

for i in trainset['image_id']:
  fid = i

  fn = '/' + fid + '.jpg'

  if os.path.isfile(fldr1 + fn) == True:
    im_paths.append(fldr1+fn)
  else:
    im_paths.append(fldr2+fn)

# %%
trainset['image_paths'] = im_paths

trainset
# Out:
#          lesion_id      image_id     dx dx_type   age     sex  \
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male
# ...            ...           ...    ...     ...   ...     ...
# 10009  HAM_0005705  ISIC_0031430  akiec   histo  75.0  female
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female
#
#           localization       dataset  label  \
# 0                scalp  vidir_modern      2
# 1                scalp  vidir_modern      2
# 2                scalp  vidir_modern      2
# 3                scalp  vidir_modern      2
# 4                  ear  vidir_modern      2
# ...                ...           ...    ...
# 10009  lower extremity  vidir_modern      0
# 10011          abdomen  vidir_modern      0
# 10012          abdomen  vidir_modern      0
# 10013             face  vidir_modern      0
# 10014             back  vidir_modern      4
#
#                                             image_paths
# 0      /content/HAM10000_images_part_1/ISIC_0027419.jpg
# 1      /content/HAM10000_images_part_1/ISIC_0025030.jpg
# 2      /content/HAM10000_images_part_1/ISIC_0026769.jpg
# 3      /content/HAM10000_images_part_1/ISIC_0025661.jpg
# 4      /content/HAM10000_images_part_2/ISIC_0031633.jpg
# ...                                                 ...
# 10009  /content/HAM10000_images_part_2/ISIC_0031430.jpg
# 10011  /content/HAM10000_images_part_2/ISIC_0033550.jpg
# 10012  /content/HAM10000_images_part_2/ISIC_0033536.jpg
# 10013  /content/HAM10000_images_part_2/ISIC_0032854.jpg
# 10014  /content/HAM10000_images_part_2/ISIC_0032258.jpg
#
# [9490 rows x 10 columns]

# %%
fldr1 = '/content/HAM10000_images_part_1'
fldr2 = '/content/HAM10000_images_part_2'

im_paths2 = []

for i in ts_balanced['image_id']:
  fid = i

  fn = '/' + fid + '.jpg'

  if os.path.isfile(fldr1 + fn) == True:
    im_paths2.append(fldr1+fn)
  else:
    im_paths2.append(fldr2+fn)

# %%
ts_balanced['image_paths'] = im_paths2
ts_balanced
# Out:
#         image_id     dx  label  \
# 0   ISIC_0033084  akiec      0
# 1   ISIC_0027178  akiec      0
# 2   ISIC_0030491  akiec      0
# 3   ISIC_0028619  akiec      0
# 4   ISIC_0027529  akiec      0
# ..           ...    ...    ...
# 70  ISIC_0026876   vasc      6
# 71  ISIC_0029889   vasc      6
# 72  ISIC_0027937   vasc      6
# 73  ISIC_0032867   vasc      6
# 74  ISIC_0032775   vasc      6
#
#                                          image_paths
# 0   /content/HAM10000_images_part_2/ISIC_0033084.jpg
# 1   /content/HAM10000_images_part_1/ISIC_0027178.jpg
# 2   /content/HAM10000_images_part_2/ISIC_0030491.jpg
# 3   /content/HAM10000_images_part_1/ISIC_0028619.jpg
# 4   /content/HAM10000_images_part_1/ISIC_0027529.jpg
# ..                                               ...
# 70  /content/HAM10000_images_part_1/ISIC_0026876.jpg
# 71  /content/HAM10000_images_part_2/ISIC_0029889.jpg
# 72  /content/HAM10000_images_part_1/ISIC_0027937.jpg
# 73  /content/HAM10000_images_part_2/ISIC_0032867.jpg
# 74  /content/HAM10000_images_part_2/ISIC_0032775.jpg
#
# [525 rows x 4 columns]

# %%
#seperate data into diagnoses
dx_0 = trainset[trainset['label'] == 0]
dx_1 = trainset[trainset['label'] == 1]
dx_2 = trainset[trainset['label'] == 2]
dx_3 = trainset[trainset['label'] == 3]
dx_4 = trainset[trainset['label'] == 4]
dx_5 = trainset[trainset['label'] == 5]
dx_6 = trainset[trainset['label'] == 6]

# %%
from pandas.core.common import random_state
#subset and random resample of data by diagnosis
n = 1000
dx_0_balanced = resample(dx_0, replace=True, n_samples=n, random_state=42) 
dx_1_balanced = resample(dx_1, replace=True, n_samples=n, random_state=42) 
dx_2_balanced = resample(dx_2, replace=True, n_samples=n, random_state=42)
dx_3_balanced = resample(dx_3, replace=True, n_samples=n, random_state=42)
dx_4_balanced = resample(dx_4, replace=True, n_samples=n, random_state=42)
dx_5_balanced = resample(dx_5, replace=True, n_samples=n, random_state=42)
dx_6_balanced = resample(dx_6, replace=True, n_samples=n, random_state=42)

# %%
trainset_balanced = pd.concat([dx_0_balanced, dx_1_balanced, dx_2_balanced, dx_3_balanced, dx_4_balanced, dx_5_balanced, dx_6_balanced])

trainset_balanced
# Out:
#         lesion_id      image_id     dx    dx_type   age     sex  \
# 9822  HAM_0000552  ISIC_0026083  akiec      histo  55.0    male
# 9925  HAM_0006301  ISIC_0024468  akiec      histo  75.0    male
# 9810  HAM_0006434  ISIC_0028314  akiec      histo  60.0    male
# 9703  HAM_0001495  ISIC_0024913  akiec      histo  85.0    male
# 9827  HAM_0003380  ISIC_0024418  akiec      histo  75.0  female
# ...           ...           ...    ...        ...   ...     ...
# 2325  HAM_0005155  ISIC_0025321   vasc      histo  85.0    male
# 2369  HAM_0006946  ISIC_0032866   vasc      histo  55.0  female
# 2445  HAM_0001091  ISIC_0031955   vasc  consensus  30.0  female
# 2375  HAM_0005989  ISIC_0033123   vasc      histo  25.0  female
# 2401  HAM_0006852  ISIC_0033991   vasc  consensus  45.0  female
#
#          localization        dataset  label  \
# 9822  lower extremity      rosendahl      0
# 9925             neck      rosendahl      0
# 9810  lower extremity      rosendahl      0
# 9703             back   vidir_modern      0
# 9827  lower extremity      rosendahl      0
# ...               ...            ...    ...
# 2325  lower extremity   vidir_modern      6
# 2369             back   vidir_modern      6
# 2445  lower extremity  vidir_molemax      6
# 2375             back   vidir_modern      6
# 2401          abdomen   vidir_modern      6
#
#                                            image_paths
# 9822  /content/HAM10000_images_part_1/ISIC_0026083.jpg
# 9925  /content/HAM10000_images_part_1/ISIC_0024468.jpg
# 9810  /content/HAM10000_images_part_1/ISIC_0028314.jpg
# 9703  /content/HAM10000_images_part_1/ISIC_0024913.jpg
# 9827  /content/HAM10000_images_part_1/ISIC_0024418.jpg
# ...                                                ...
# 2325  /content/HAM10000_images_part_1/ISIC_0025321.jpg
# 2369  /content/HAM10000_images_part_2/ISIC_0032866.jpg
# 2445  /content/HAM10000_images_part_2/ISIC_0031955.jpg
# 2375  /content/HAM10000_images_part_2/ISIC_0033123.jpg
# 2401  /content/HAM10000_images_part_2/ISIC_0033991.jpg
#
# [7000 rows x 10 columns]

# %%
#turn images to array and add as a new column 
trainset_balanced['image'] = trainset_balanced['image_paths'].map(lambda x: np.asarray(Image.open(x).resize((im_size,im_size))))

# %%
ts_balanced['image'] = ts_balanced['image_paths'].map(lambda x: np.asarray(Image.open(x).resize((im_size,im_size))))

ts_balanced
# Out:
#         image_id     dx  label  \
# 0   ISIC_0033084  akiec      0
# 1   ISIC_0027178  akiec      0
# 2   ISIC_0030491  akiec      0
# 3   ISIC_0028619  akiec      0
# 4   ISIC_0027529  akiec      0
# ..           ...    ...    ...
# 70  ISIC_0026876   vasc      6
# 71  ISIC_0029889   vasc      6
# 72  ISIC_0027937   vasc      6
# 73  ISIC_0032867   vasc      6
# 74  ISIC_0032775   vasc      6
#
#                                          image_paths  \
# 0   /content/HAM10000_images_part_2/ISIC_0033084.jpg
# 1   /content/HAM10000_images_part_1/ISIC_0027178.jpg
# 2   /content/HAM10000_images_part_2/ISIC_0030491.jpg
# 3   /content/HAM10000_images_part_1/ISIC_0028619.jpg
# 4   /content/HAM10000_images_part_1/ISIC_0027529.jpg
# ..                                               ...
# 70  /content/HAM10000_images_part_1/ISIC_0026876.jpg
# 71  /content/HAM10000_images_part_2/ISIC_0029889.jpg
# 72  /content/HAM10000_images_part_1/ISIC_0027937.jpg
# 73  /content/HAM10000_images_part_2/ISIC_0032867.jpg
# 74  /content/HAM10000_images_part_2/ISIC_0032775.jpg
#
#                                                 image
# 0   [[[115, 92, 101], [108, 92, 96], [108, 91, 98]...
# 1   [[[236, 179, 198], [233, 174, 192], [234, 175,...
# 2   [[[175, 126, 124], [172, 120, 120], [169, 110,...
# 3   [[[33, 16, 19], [31, 14, 20], [31, 14, 19], [2...
# 4   [[[191, 146, 135], [188, 144, 131], [191, 147,...
# ..                                                ...
# 70  [[[209, 183, 188], [211, 184, 190], [210, 184,...
# 71  [[[121, 95, 97], [124, 97, 104], [120, 97, 107...
# 72  [[[225, 156, 165], [227, 157, 169], [228, 161,...
# 73  [[[19, 16, 13], [21, 18, 13], [23, 20, 16], [2...
# 74  [[[210, 185, 199], [214, 192, 202], [217, 193,...
#
# [525 rows x 5 columns]

# %%
X_trainset = np.asarray(trainset_balanced['image'].tolist())
X_trainset = X_trainset/255. 
Y_trainset = trainset_balanced['label']
Y_dx_trainset = to_categorical(Y_trainset, num_classes=7)

# %%
X_ts = np.asarray(ts_balanced['image'].tolist())
X_ts = X_ts/255. 
Y_ts = ts_balanced['label']
Y_dx_ts = to_categorical(Y_ts, num_classes=7)

# %%
#train/validation split - 70/30 split

x_train, x_val, y_train, y_val = train_test_split(X_trainset, Y_dx_trainset, test_size=0.30, random_state=29)

# %%
#GPU
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
#model

img_rows, img_cols = 224, 224 

vgg_mod = vgg16.VGG16(weights = 'imagenet', 
                 include_top = False, 
                 input_shape = (img_rows, img_cols, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %%
#freeze last 4 layers
for layer in vgg_mod.layers:
    layer.trainable = False

# %%
for (i,layer) in enumerate(vgg_mod.layers):
    print(str(i) + " "+ layer.__class__.__name__, layer.trainable)
# Out:
# 0 InputLayer False
# 1 Conv2D False
# 2 Conv2D False
# 3 MaxPooling2D False
# 4 Conv2D False
# 5 Conv2D False
# 6 MaxPooling2D False
# 7 Conv2D False
# 8 Conv2D False
# 9 Conv2D False
# 10 MaxPooling2D False
# 11 Conv2D False
# 12 Conv2D False
# 13 Conv2D False
# 14 MaxPooling2D False
# 15 Conv2D False
# 16 Conv2D False
# 17 Conv2D False
# 18 MaxPooling2D False

# %%
#top layers replaced by our own - 7 classes. Other layers used as is and as trained on Imagenet

def lw(bottom_model, num_classes):
    """creates the top or head of the model that will be 
    placed ontop of the bottom layers"""

    top_model = bottom_model.output
    top_model = GlobalAveragePooling2D()(top_model)
    top_model = Dense(1024,activation='relu')(top_model)
    top_model = Dense(1024,activation='relu')(top_model)
    top_model = Dense(512,activation='relu')(top_model)
    top_model = Dense(num_classes,activation='softmax')(top_model)
    return top_model

# %%
num_classes = 7

FC_Head = lw(vgg_mod, num_classes)
model = Model(inputs = vgg_mod.input, outputs = FC_Head)
print(model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              525312
#
#  dense_1 (Dense)             (None, 1024)              1049600
#
#  dense_2 (Dense)             (None, 512)               524800
#
#  dense_3 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 16,817,991
# Trainable params: 2,103,303
# Non-trainable params: 14,714,688
# _________________________________________________________________
# None

# %%
model.compile(optimizer='adam', loss = 'categorical_crossentropy',metrics = ['accuracy'])

# %%
#training

batch_size = 64
epochs = 75

# %%
mod_fit = model.fit(
    x_train, y_train,
    epochs=epochs,
    batch_size = batch_size,
    validation_data=(x_val, y_val),
    verbose=2)
# Out:
# Epoch 1/75
# 77/77 - 19s - loss: 1.7248 - accuracy: 0.3104 - val_loss: 1.5405 - val_accuracy: 0.4033 - 19s/epoch - 241ms/step
# Epoch 2/75
# 77/77 - 5s - loss: 1.4416 - accuracy: 0.4437 - val_loss: 1.3755 - val_accuracy: 0.4890 - 5s/epoch - 69ms/step
# Epoch 3/75
# 77/77 - 5s - loss: 1.2991 - accuracy: 0.5067 - val_loss: 1.3275 - val_accuracy: 0.4605 - 5s/epoch - 69ms/step
# Epoch 4/75
# 77/77 - 5s - loss: 1.2273 - accuracy: 0.5308 - val_loss: 1.2865 - val_accuracy: 0.5138 - 5s/epoch - 69ms/step
# Epoch 5/75
# 77/77 - 5s - loss: 1.1103 - accuracy: 0.5741 - val_loss: 1.0683 - val_accuracy: 0.5976 - 5s/epoch - 69ms/step
# Epoch 6/75
# 77/77 - 5s - loss: 1.0565 - accuracy: 0.5906 - val_loss: 1.1392 - val_accuracy: 0.5586 - 5s/epoch - 69ms/step
# Epoch 7/75
# 77/77 - 5s - loss: 0.9675 - accuracy: 0.6306 - val_loss: 1.0578 - val_accuracy: 0.5881 - 5s/epoch - 70ms/step
# Epoch 8/75
# 77/77 - 5s - loss: 0.9100 - accuracy: 0.6578 - val_loss: 0.9461 - val_accuracy: 0.6457 - 5s/epoch - 70ms/step
# Epoch 9/75
# 77/77 - 5s - loss: 0.8370 - accuracy: 0.6808 - val_loss: 1.0035 - val_accuracy: 0.6114 - 5s/epoch - 69ms/step
# Epoch 10/75
# 77/77 - 5s - loss: 0.7762 - accuracy: 0.7051 - val_loss: 0.8270 - val_accuracy: 0.6938 - 5s/epoch - 69ms/step
# Epoch 11/75
# 77/77 - 5s - loss: 0.7988 - accuracy: 0.6986 - val_loss: 0.8200 - val_accuracy: 0.7062 - 5s/epoch - 69ms/step
# Epoch 12/75
# 77/77 - 5s - loss: 0.7020 - accuracy: 0.7322 - val_loss: 0.7995 - val_accuracy: 0.7019 - 5s/epoch - 69ms/step
# Epoch 13/75
# 77/77 - 5s - loss: 0.6535 - accuracy: 0.7486 - val_loss: 0.8019 - val_accuracy: 0.7105 - 5s/epoch - 69ms/step
# Epoch 14/75
# 77/77 - 5s - loss: 0.6504 - accuracy: 0.7596 - val_loss: 0.8438 - val_accuracy: 0.6919 - 5s/epoch - 70ms/step
# Epoch 15/75
# 77/77 - 5s - loss: 0.5852 - accuracy: 0.7814 - val_loss: 0.7181 - val_accuracy: 0.7433 - 5s/epoch - 70ms/step
# Epoch 16/75
# 77/77 - 5s - loss: 0.6774 - accuracy: 0.7441 - val_loss: 0.7587 - val_accuracy: 0.7238 - 5s/epoch - 69ms/step
# Epoch 17/75
# 77/77 - 5s - loss: 0.5742 - accuracy: 0.7867 - val_loss: 0.7834 - val_accuracy: 0.7252 - 5s/epoch - 69ms/step
# Epoch 18/75
# 77/77 - 5s - loss: 0.5322 - accuracy: 0.7961 - val_loss: 0.7239 - val_accuracy: 0.7386 - 5s/epoch - 69ms/step
# Epoch 19/75
# 77/77 - 5s - loss: 0.5951 - accuracy: 0.7786 - val_loss: 0.7528 - val_accuracy: 0.7376 - 5s/epoch - 70ms/step
# Epoch 20/75
# 77/77 - 5s - loss: 0.4969 - accuracy: 0.8122 - val_loss: 0.7052 - val_accuracy: 0.7581 - 5s/epoch - 69ms/step
# Epoch 21/75
# 77/77 - 5s - loss: 0.5044 - accuracy: 0.8104 - val_loss: 0.6633 - val_accuracy: 0.7633 - 5s/epoch - 69ms/step
# Epoch 22/75
# 77/77 - 5s - loss: 0.4240 - accuracy: 0.8408 - val_loss: 0.7803 - val_accuracy: 0.7424 - 5s/epoch - 69ms/step
# Epoch 23/75
# 77/77 - 5s - loss: 0.4445 - accuracy: 0.8371 - val_loss: 0.7124 - val_accuracy: 0.7638 - 5s/epoch - 69ms/step
# Epoch 24/75
# 77/77 - 5s - loss: 0.4531 - accuracy: 0.8312 - val_loss: 0.7186 - val_accuracy: 0.7438 - 5s/epoch - 68ms/step
# Epoch 25/75
# 77/77 - 5s - loss: 0.3941 - accuracy: 0.8547 - val_loss: 0.7049 - val_accuracy: 0.7848 - 5s/epoch - 69ms/step
# Epoch 26/75
# 77/77 - 5s - loss: 0.4263 - accuracy: 0.8418 - val_loss: 0.7324 - val_accuracy: 0.7619 - 5s/epoch - 69ms/step
# Epoch 27/75
# 77/77 - 5s - loss: 0.4003 - accuracy: 0.8500 - val_loss: 0.6268 - val_accuracy: 0.8033 - 5s/epoch - 69ms/step
# Epoch 28/75
# 77/77 - 5s - loss: 0.3535 - accuracy: 0.8698 - val_loss: 0.7708 - val_accuracy: 0.7733 - 5s/epoch - 70ms/step
# Epoch 29/75
# 77/77 - 5s - loss: 0.3586 - accuracy: 0.8702 - val_loss: 0.7313 - val_accuracy: 0.7800 - 5s/epoch - 69ms/step
# Epoch 30/75
# 77/77 - 5s - loss: 0.3525 - accuracy: 0.8767 - val_loss: 0.7709 - val_accuracy: 0.7671 - 5s/epoch - 69ms/step
# Epoch 31/75
# 77/77 - 5s - loss: 0.3539 - accuracy: 0.8692 - val_loss: 0.6634 - val_accuracy: 0.7967 - 5s/epoch - 69ms/step
# Epoch 32/75
# 77/77 - 5s - loss: 0.3658 - accuracy: 0.8655 - val_loss: 0.7238 - val_accuracy: 0.7676 - 5s/epoch - 70ms/step
# Epoch 33/75
# 77/77 - 5s - loss: 0.3216 - accuracy: 0.8831 - val_loss: 0.6149 - val_accuracy: 0.8248 - 5s/epoch - 69ms/step
# Epoch 34/75
# 77/77 - 5s - loss: 0.2573 - accuracy: 0.9116 - val_loss: 0.6569 - val_accuracy: 0.8138 - 5s/epoch - 69ms/step
# Epoch 35/75
# 77/77 - 5s - loss: 0.2689 - accuracy: 0.9039 - val_loss: 0.6204 - val_accuracy: 0.8352 - 5s/epoch - 69ms/step
# Epoch 36/75
# 77/77 - 5s - loss: 0.2539 - accuracy: 0.9106 - val_loss: 0.7323 - val_accuracy: 0.7943 - 5s/epoch - 69ms/step
# Epoch 37/75
# 77/77 - 5s - loss: 0.2773 - accuracy: 0.9027 - val_loss: 0.7375 - val_accuracy: 0.7967 - 5s/epoch - 69ms/step
# Epoch 38/75
# 77/77 - 5s - loss: 0.2773 - accuracy: 0.9022 - val_loss: 0.7122 - val_accuracy: 0.8048 - 5s/epoch - 70ms/step
# Epoch 39/75
# 77/77 - 5s - loss: 0.2293 - accuracy: 0.9186 - val_loss: 0.6886 - val_accuracy: 0.8200 - 5s/epoch - 70ms/step
# Epoch 40/75
# 77/77 - 5s - loss: 0.2408 - accuracy: 0.9120 - val_loss: 0.7338 - val_accuracy: 0.8033 - 5s/epoch - 69ms/step
# Epoch 41/75
# 77/77 - 5s - loss: 0.2577 - accuracy: 0.9086 - val_loss: 0.7210 - val_accuracy: 0.8290 - 5s/epoch - 69ms/step
# Epoch 42/75
# 77/77 - 5s - loss: 0.1863 - accuracy: 0.9335 - val_loss: 0.7383 - val_accuracy: 0.8424 - 5s/epoch - 69ms/step
# Epoch 43/75
# 77/77 - 5s - loss: 0.1953 - accuracy: 0.9294 - val_loss: 0.6522 - val_accuracy: 0.8462 - 5s/epoch - 69ms/step
# Epoch 44/75
# 77/77 - 5s - loss: 0.2167 - accuracy: 0.9227 - val_loss: 0.7971 - val_accuracy: 0.8076 - 5s/epoch - 69ms/step
# Epoch 45/75
# 77/77 - 5s - loss: 0.2289 - accuracy: 0.9194 - val_loss: 0.7391 - val_accuracy: 0.8357 - 5s/epoch - 69ms/step
# Epoch 46/75
# 77/77 - 5s - loss: 0.2254 - accuracy: 0.9198 - val_loss: 0.6889 - val_accuracy: 0.8367 - 5s/epoch - 69ms/step
# Epoch 47/75
# 77/77 - 5s - loss: 0.2101 - accuracy: 0.9233 - val_loss: 0.6593 - val_accuracy: 0.8381 - 5s/epoch - 69ms/step
# Epoch 48/75
# 77/77 - 5s - loss: 0.2140 - accuracy: 0.9241 - val_loss: 0.7181 - val_accuracy: 0.8300 - 5s/epoch - 69ms/step
# Epoch 49/75
# 77/77 - 5s - loss: 0.1978 - accuracy: 0.9302 - val_loss: 0.8191 - val_accuracy: 0.8233 - 5s/epoch - 69ms/step
# Epoch 50/75
# 77/77 - 5s - loss: 0.1656 - accuracy: 0.9412 - val_loss: 0.7864 - val_accuracy: 0.8319 - 5s/epoch - 69ms/step
# Epoch 51/75
# 77/77 - 5s - loss: 0.1698 - accuracy: 0.9392 - val_loss: 0.8855 - val_accuracy: 0.8129 - 5s/epoch - 69ms/step
# Epoch 52/75
# 77/77 - 5s - loss: 0.2621 - accuracy: 0.9047 - val_loss: 0.7389 - val_accuracy: 0.8362 - 5s/epoch - 69ms/step
# Epoch 53/75
# 77/77 - 5s - loss: 0.1637 - accuracy: 0.9418 - val_loss: 0.7209 - val_accuracy: 0.8300 - 5s/epoch - 69ms/step
# Epoch 54/75
# 77/77 - 5s - loss: 0.1662 - accuracy: 0.9427 - val_loss: 0.7123 - val_accuracy: 0.8519 - 5s/epoch - 69ms/step
# Epoch 55/75
# 77/77 - 5s - loss: 0.1487 - accuracy: 0.9469 - val_loss: 0.7664 - val_accuracy: 0.8490 - 5s/epoch - 69ms/step
# Epoch 56/75
# 77/77 - 5s - loss: 0.1337 - accuracy: 0.9545 - val_loss: 0.7702 - val_accuracy: 0.8529 - 5s/epoch - 69ms/step
# Epoch 57/75
# 77/77 - 5s - loss: 0.1144 - accuracy: 0.9620 - val_loss: 0.9100 - val_accuracy: 0.8400 - 5s/epoch - 69ms/step
# Epoch 58/75
# 77/77 - 5s - loss: 0.2260 - accuracy: 0.9192 - val_loss: 0.7504 - val_accuracy: 0.8238 - 5s/epoch - 69ms/step
# Epoch 59/75
# 77/77 - 5s - loss: 0.1348 - accuracy: 0.9504 - val_loss: 0.7135 - val_accuracy: 0.8605 - 5s/epoch - 69ms/step
# Epoch 60/75
# 77/77 - 5s - loss: 0.1238 - accuracy: 0.9563 - val_loss: 0.8620 - val_accuracy: 0.8405 - 5s/epoch - 70ms/step
# Epoch 61/75
# 77/77 - 5s - loss: 0.1241 - accuracy: 0.9541 - val_loss: 0.8873 - val_accuracy: 0.8410 - 5s/epoch - 69ms/step
# Epoch 62/75
# 77/77 - 5s - loss: 0.1193 - accuracy: 0.9588 - val_loss: 0.8581 - val_accuracy: 0.8462 - 5s/epoch - 70ms/step
# Epoch 63/75
# 77/77 - 5s - loss: 0.1653 - accuracy: 0.9408 - val_loss: 1.0779 - val_accuracy: 0.7833 - 5s/epoch - 69ms/step
# Epoch 64/75
# 77/77 - 5s - loss: 0.1370 - accuracy: 0.9537 - val_loss: 0.8513 - val_accuracy: 0.8419 - 5s/epoch - 70ms/step
# Epoch 65/75
# 77/77 - 5s - loss: 0.0956 - accuracy: 0.9667 - val_loss: 0.7450 - val_accuracy: 0.8633 - 5s/epoch - 69ms/step
# Epoch 66/75
# 77/77 - 5s - loss: 0.1082 - accuracy: 0.9610 - val_loss: 0.8859 - val_accuracy: 0.8438 - 5s/epoch - 69ms/step
# Epoch 67/75
# 77/77 - 5s - loss: 0.0933 - accuracy: 0.9657 - val_loss: 1.0654 - val_accuracy: 0.8200 - 5s/epoch - 70ms/step
# Epoch 68/75
# 77/77 - 5s - loss: 0.1575 - accuracy: 0.9455 - val_loss: 0.9143 - val_accuracy: 0.8410 - 5s/epoch - 68ms/step
# Epoch 69/75
# 77/77 - 5s - loss: 0.1142 - accuracy: 0.9598 - val_loss: 0.8208 - val_accuracy: 0.8552 - 5s/epoch - 69ms/step
# Epoch 70/75
# 77/77 - 5s - loss: 0.0797 - accuracy: 0.9737 - val_loss: 0.8617 - val_accuracy: 0.8633 - 5s/epoch - 69ms/step
# Epoch 71/75
# 77/77 - 5s - loss: 0.0967 - accuracy: 0.9694 - val_loss: 1.0569 - val_accuracy: 0.8381 - 5s/epoch - 69ms/step
# Epoch 72/75
# 77/77 - 5s - loss: 0.0821 - accuracy: 0.9714 - val_loss: 0.9346 - val_accuracy: 0.8514 - 5s/epoch - 69ms/step
# Epoch 73/75
# 77/77 - 5s - loss: 0.1018 - accuracy: 0.9647 - val_loss: 0.8429 - val_accuracy: 0.8619 - 5s/epoch - 68ms/step
# Epoch 74/75
# 77/77 - 5s - loss: 0.0626 - accuracy: 0.9806 - val_loss: 0.9502 - val_accuracy: 0.8590 - 5s/epoch - 69ms/step
# Epoch 75/75
# 77/77 - 5s - loss: 0.0974 - accuracy: 0.9639 - val_loss: 0.9584 - val_accuracy: 0.8629 - 5s/epoch - 69ms/step

# %%
mod_acc_val = model.evaluate(x_val, y_val)
print('Validation accuracy:', mod_acc_val[1])
# Out:
# 66/66 [==============================] - 3s 33ms/step - loss: 0.9585 - accuracy: 0.8624
# Validation accuracy: 0.8623809814453125

# %%
loss = mod_fit.history['loss']
val_loss = mod_fit.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = mod_fit.history['accuracy']
val_acc = mod_fit.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
y_pred = model.predict(X_ts)
# Out:
# 17/17 [==============================] - 1s 44ms/step

# %%
#one hot encoding --> probs from softmax to 1 and 0
y_pred_classes = np.argmax(y_pred, axis = 1)

# %%
y_true = np.argmax(Y_dx_ts, axis = 1)

# %%
cm = confusion_matrix(y_true, y_pred_classes)
fig, ax = plt.subplots(figsize=(10,10))
sns.set(font_scale=1.6)
sns.heatmap(cm, annot=True, linewidths=.5, ax=ax)

# %%
incorr_fraction = 1 - np.diag(cm) / np.sum(cm, axis=1)

incorr_fraction = incorr_fraction.tolist()

incorr_fraction = [round(item, 2) for item in incorr_fraction]

incorr_fraction
# Out:
# [0.4, 0.33, 0.47, 0.79, 0.6, 0.33, 0.4]

# %%
#percent misclassified per dx
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i], ha = 'center')
  
if __name__ == '__main__':
  plt.bar(np.arange(7), incorr_fraction)
  addlabels(np.arange(7), incorr_fraction)
  plt.title("Fraction Misclassified per Diagnosis Label")
  plt.xlabel('True Label')
  plt.ylabel('Fraction of incorrect predictions')

# %%
mod_acc_test = model.evaluate(X_ts, Y_dx_ts)
print('Test accuracy:', mod_acc_test[1])
# Out:
# 17/17 [==============================] - 0s 25ms/step - loss: 5.0933 - accuracy: 0.5257
# Test accuracy: 0.5257142782211304

# %%
#reference
#https://www.youtube.com/watch?v=Fxy6WTnUIww
#https://keras.io/api/layers/core_layers/dense/
#https://keras.io/api/models/model/
#https://www.educba.com/keras-fit/
#https://www.geeksforgeeks.org/adding-value-labels-on-a-matplotlib-bar-chart/
#https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.transpose.html
#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.from_dict.html
#https://www.geeksforgeeks.org/drop-rows-from-the-dataframe-based-on-certain-condition-applied-on-a-column/
#https://sparkbyexamples.com/pandas/conver-pandas-column-to-list/
#https://datascience.stackexchange.com/questions/37227/how-to-remove-rows-from-a-dataframe-that-are-identical-to-another-dataframe
