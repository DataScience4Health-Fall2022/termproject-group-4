# %%
#import statements
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from glob import glob
from tqdm._tqdm_notebook import tqdm_notebook as tqdm
import seaborn as sns
from PIL import Image
import tensorflow as tf
from google.colab import drive
from sklearn.metrics import confusion_matrix
import keras
from keras.utils.np_utils import to_categorical 
from keras.models import Model
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D, BatchNormalization, Activation, GlobalAveragePooling2D, ZeroPadding2D
from keras.applications import vgg16
from sklearn.model_selection import train_test_split
from scipy import stats
from sklearn import preprocessing
from sklearn.preprocessing import LabelEncoder
from sklearn.utils import resample
from tensorflow.keras.models import Model
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.*` instead of `tqdm._tqdm_notebook.*`
#   import sys

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! unzip '/content/drive/MyDrive/HAM10000_metadata_gc.zip'
# Out:
# Archive:  /content/drive/MyDrive/HAM10000_metadata_gc.zip
#   inflating: HAM10000_metadata

# %%
! unzip '/content/drive/MyDrive/HAM10000_images_part_1_gc'

# %%
! unzip '/content/drive/MyDrive/HAM10000_images_part_2_gc'

# %%
md = pd.read_csv("/content/HAM10000_metadata")
md
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization  \
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10013  HAM_0000239  ISIC_0032854  akiec   histo  80.0    male         face
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
#             dataset
# 0      vidir_modern
# 1      vidir_modern
# 2      vidir_modern
# 3      vidir_modern
# 4      vidir_modern
# ...             ...
# 10010  vidir_modern
# 10011  vidir_modern
# 10012  vidir_modern
# 10013  vidir_modern
# 10014  vidir_modern
#
# [10015 rows x 8 columns]

# %%
#vgg16 model accepts images of 224X224X3
im_size = 224

# %%
#set aside a portion of full dataset for testing
dxs = md["dx"].unique()

ldxs = {}

for dx, group in md.groupby("dx"):
    ldxs[dx] = []
    images = list(group["image_id"])
    np.random.shuffle(images)
    for i in range(75):
        ldxs[dx].append(images[i])

# %%
ts = pd.DataFrame.from_dict(ldxs, orient='index')
ts = ts.T
ts
# Out:
#            akiec           bcc           bkl            df           mel  \
# 0   ISIC_0026765  ISIC_0025711  ISIC_0030583  ISIC_0033554  ISIC_0034173
# 1   ISIC_0033151  ISIC_0031056  ISIC_0027463  ISIC_0025373  ISIC_0032081
# 2   ISIC_0029315  ISIC_0032696  ISIC_0030698  ISIC_0033695  ISIC_0025751
# 3   ISIC_0025712  ISIC_0028719  ISIC_0027680  ISIC_0031827  ISIC_0033324
# 4   ISIC_0032203  ISIC_0032316  ISIC_0027533  ISIC_0026313  ISIC_0033612
# ..           ...           ...           ...           ...           ...
# 70  ISIC_0026327  ISIC_0028747  ISIC_0032359  ISIC_0030442  ISIC_0031377
# 71  ISIC_0026152  ISIC_0034306  ISIC_0027027  ISIC_0031002  ISIC_0027171
# 72  ISIC_0026984  ISIC_0033001  ISIC_0028876  ISIC_0025980  ISIC_0026089
# 73  ISIC_0030191  ISIC_0024472  ISIC_0029425  ISIC_0024845  ISIC_0024367
# 74  ISIC_0029025  ISIC_0031298  ISIC_0024489  ISIC_0033005  ISIC_0025097
#
#               nv          vasc
# 0   ISIC_0028012  ISIC_0025680
# 1   ISIC_0027031  ISIC_0032614
# 2   ISIC_0032551  ISIC_0027903
# 3   ISIC_0028535  ISIC_0030275
# 4   ISIC_0026027  ISIC_0026490
# ..           ...           ...
# 70  ISIC_0029507  ISIC_0027790
# 71  ISIC_0027430  ISIC_0024662
# 72  ISIC_0033556  ISIC_0032240
# 73  ISIC_0033737  ISIC_0032538
# 74  ISIC_0032500  ISIC_0032692
#
# [75 rows x 7 columns]

# %%
t_akiec_imid = ts.akiec.values.tolist()
t_akiec_dx = ['akiec'] * 75
ts_aikec = pd.DataFrame(list(zip(t_akiec_imid, t_akiec_dx)), columns=['image_id', 'dx'])

t_bcc_imid = ts.bcc.values.tolist()
t_bcc_dx = ['bcc'] * 75
ts_bcc = pd.DataFrame(list(zip(t_bcc_imid, t_bcc_dx)), columns=['image_id', 'dx'])

t_bkl_imid = ts.bkl.values.tolist()
t_bkl_dx = ['bkl'] * 75
ts_bkl = pd.DataFrame(list(zip(t_bkl_imid, t_bkl_dx)), columns=['image_id', 'dx'])

t_df_imid = ts.df.values.tolist()
t_df_dx = ['df'] * 75
ts_df = pd.DataFrame(list(zip(t_df_imid, t_df_dx)), columns=['image_id', 'dx'])

t_mel_imid = ts.mel.values.tolist()
t_mel_dx = ['mel'] * 75
ts_mel = pd.DataFrame(list(zip(t_mel_imid, t_mel_dx)), columns=['image_id', 'dx'])

t_nv_imid = ts.nv.values.tolist()
t_nv_dx = ['nv'] * 75
ts_nv = pd.DataFrame(list(zip(t_nv_imid, t_nv_dx)), columns=['image_id', 'dx'])

t_vasc_imid = ts.vasc.values.tolist()
t_vasc_dx = ['vasc'] * 75
ts_vasc = pd.DataFrame(list(zip(t_vasc_imid, t_vasc_dx)), columns=['image_id', 'dx'])

ts_balanced = pd.concat([ts_aikec, ts_bcc, ts_bkl, ts_df, ts_mel, ts_nv, ts_vasc])
ts_balanced
# Out:
#         image_id     dx
# 0   ISIC_0026765  akiec
# 1   ISIC_0033151  akiec
# 2   ISIC_0029315  akiec
# 3   ISIC_0025712  akiec
# 4   ISIC_0032203  akiec
# ..           ...    ...
# 70  ISIC_0027790   vasc
# 71  ISIC_0024662   vasc
# 72  ISIC_0032240   vasc
# 73  ISIC_0032538   vasc
# 74  ISIC_0032692   vasc
#
# [525 rows x 2 columns]

# %%
cond = md['image_id'].isin(ts_balanced['image_id'])
trainset = md.drop(md[cond].index)

trainset
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization  \
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10005  HAM_0005579  ISIC_0028393  akiec   histo  80.0    male         face
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
#             dataset
# 0      vidir_modern
# 1      vidir_modern
# 2      vidir_modern
# 3      vidir_modern
# 4      vidir_modern
# ...             ...
# 10005     rosendahl
# 10010  vidir_modern
# 10011  vidir_modern
# 10012  vidir_modern
# 10014  vidir_modern
#
# [9490 rows x 8 columns]

# %%
#label encoding: going from text to numerical
lab_enc = LabelEncoder()
lab_enc.fit(trainset['dx'])
LabelEncoder()
print(list(lab_enc.classes_))
# Out:
# ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']

# %%
lab_enc = LabelEncoder()
lab_enc.fit(ts_balanced['dx'])
LabelEncoder()
print(list(lab_enc.classes_))
# Out:
# ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']

# %%
#label column in md - diagnosis and numerical label in one dataset
trainset['label'] = lab_enc.transform(trainset["dx"]) 
ts_balanced['label'] = lab_enc.transform(ts_balanced["dx"]) 
trainset
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization  \
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10005  HAM_0005579  ISIC_0028393  akiec   histo  80.0    male         face
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
#             dataset  label
# 0      vidir_modern      2
# 1      vidir_modern      2
# 2      vidir_modern      2
# 3      vidir_modern      2
# 4      vidir_modern      2
# ...             ...    ...
# 10005     rosendahl      0
# 10010  vidir_modern      0
# 10011  vidir_modern      0
# 10012  vidir_modern      0
# 10014  vidir_modern      4
#
# [9490 rows x 9 columns]

# %%
ts_balanced
# Out:
#         image_id     dx  label
# 0   ISIC_0026765  akiec      0
# 1   ISIC_0033151  akiec      0
# 2   ISIC_0029315  akiec      0
# 3   ISIC_0025712  akiec      0
# 4   ISIC_0032203  akiec      0
# ..           ...    ...    ...
# 70  ISIC_0027790   vasc      6
# 71  ISIC_0024662   vasc      6
# 72  ISIC_0032240   vasc      6
# 73  ISIC_0032538   vasc      6
# 74  ISIC_0032692   vasc      6
#
# [525 rows x 3 columns]

# %%
#get all file paths and make a new column
fldr1 = '/content/HAM10000_images_part_1'
fldr2 = '/content/HAM10000_images_part_2'

im_paths = []

for i in trainset['image_id']:
  fid = i

  fn = '/' + fid + '.jpg'

  if os.path.isfile(fldr1 + fn) == True:
    im_paths.append(fldr1+fn)
  else:
    im_paths.append(fldr2+fn)

# %%
trainset['image_paths'] = im_paths

trainset
# Out:
#          lesion_id      image_id     dx dx_type   age     sex localization  \
# 0      HAM_0000118  ISIC_0027419    bkl   histo  80.0    male        scalp
# 1      HAM_0000118  ISIC_0025030    bkl   histo  80.0    male        scalp
# 2      HAM_0002730  ISIC_0026769    bkl   histo  80.0    male        scalp
# 3      HAM_0002730  ISIC_0025661    bkl   histo  80.0    male        scalp
# 4      HAM_0001466  ISIC_0031633    bkl   histo  75.0    male          ear
# ...            ...           ...    ...     ...   ...     ...          ...
# 10005  HAM_0005579  ISIC_0028393  akiec   histo  80.0    male         face
# 10010  HAM_0002867  ISIC_0033084  akiec   histo  40.0    male      abdomen
# 10011  HAM_0002867  ISIC_0033550  akiec   histo  40.0    male      abdomen
# 10012  HAM_0002867  ISIC_0033536  akiec   histo  40.0    male      abdomen
# 10014  HAM_0003521  ISIC_0032258    mel   histo  70.0  female         back
#
#             dataset  label                                       image_paths
# 0      vidir_modern      2  /content/HAM10000_images_part_1/ISIC_0027419.jpg
# 1      vidir_modern      2  /content/HAM10000_images_part_1/ISIC_0025030.jpg
# 2      vidir_modern      2  /content/HAM10000_images_part_1/ISIC_0026769.jpg
# 3      vidir_modern      2  /content/HAM10000_images_part_1/ISIC_0025661.jpg
# 4      vidir_modern      2  /content/HAM10000_images_part_2/ISIC_0031633.jpg
# ...             ...    ...                                               ...
# 10005     rosendahl      0  /content/HAM10000_images_part_1/ISIC_0028393.jpg
# 10010  vidir_modern      0  /content/HAM10000_images_part_2/ISIC_0033084.jpg
# 10011  vidir_modern      0  /content/HAM10000_images_part_2/ISIC_0033550.jpg
# 10012  vidir_modern      0  /content/HAM10000_images_part_2/ISIC_0033536.jpg
# 10014  vidir_modern      4  /content/HAM10000_images_part_2/ISIC_0032258.jpg
#
# [9490 rows x 10 columns]

# %%
fldr1 = '/content/HAM10000_images_part_1'
fldr2 = '/content/HAM10000_images_part_2'

im_paths2 = []

for i in ts_balanced['image_id']:
  fid = i

  fn = '/' + fid + '.jpg'

  if os.path.isfile(fldr1 + fn) == True:
    im_paths2.append(fldr1+fn)
  else:
    im_paths2.append(fldr2+fn)

# %%
ts_balanced['image_paths'] = im_paths2
ts_balanced
# Out:
#         image_id     dx  label  \
# 0   ISIC_0026765  akiec      0
# 1   ISIC_0033151  akiec      0
# 2   ISIC_0029315  akiec      0
# 3   ISIC_0025712  akiec      0
# 4   ISIC_0032203  akiec      0
# ..           ...    ...    ...
# 70  ISIC_0027790   vasc      6
# 71  ISIC_0024662   vasc      6
# 72  ISIC_0032240   vasc      6
# 73  ISIC_0032538   vasc      6
# 74  ISIC_0032692   vasc      6
#
#                                          image_paths
# 0   /content/HAM10000_images_part_1/ISIC_0026765.jpg
# 1   /content/HAM10000_images_part_2/ISIC_0033151.jpg
# 2   /content/HAM10000_images_part_2/ISIC_0029315.jpg
# 3   /content/HAM10000_images_part_1/ISIC_0025712.jpg
# 4   /content/HAM10000_images_part_2/ISIC_0032203.jpg
# ..                                               ...
# 70  /content/HAM10000_images_part_1/ISIC_0027790.jpg
# 71  /content/HAM10000_images_part_1/ISIC_0024662.jpg
# 72  /content/HAM10000_images_part_2/ISIC_0032240.jpg
# 73  /content/HAM10000_images_part_2/ISIC_0032538.jpg
# 74  /content/HAM10000_images_part_2/ISIC_0032692.jpg
#
# [525 rows x 4 columns]

# %%
#seperate data into diagnoses
dx_0 = trainset[trainset['label'] == 0]
dx_1 = trainset[trainset['label'] == 1]
dx_2 = trainset[trainset['label'] == 2]
dx_3 = trainset[trainset['label'] == 3]
dx_4 = trainset[trainset['label'] == 4]
dx_5 = trainset[trainset['label'] == 5]
dx_6 = trainset[trainset['label'] == 6]

# %%
from pandas.core.common import random_state
#subset and random resample of data by diagnosis
n = 1000
dx_0_balanced = resample(dx_0, replace=True, n_samples=n, random_state=42) 
dx_1_balanced = resample(dx_1, replace=True, n_samples=n, random_state=42) 
dx_2_balanced = resample(dx_2, replace=True, n_samples=n, random_state=42)
dx_3_balanced = resample(dx_3, replace=True, n_samples=n, random_state=42)
dx_4_balanced = resample(dx_4, replace=True, n_samples=n, random_state=42)
dx_5_balanced = resample(dx_5, replace=True, n_samples=n, random_state=42)
dx_6_balanced = resample(dx_6, replace=True, n_samples=n, random_state=42)

# %%
trainset_balanced = pd.concat([dx_0_balanced, dx_1_balanced, dx_2_balanced, dx_3_balanced, dx_4_balanced, dx_5_balanced, dx_6_balanced])

trainset_balanced
# Out:
#         lesion_id      image_id     dx    dx_type   age     sex  \
# 9812  HAM_0005264  ISIC_0029371  akiec      histo  45.0    male
# 9914  HAM_0005551  ISIC_0029900  akiec      histo  60.0    male
# 9797  HAM_0006481  ISIC_0027753  akiec      histo  70.0    male
# 9704  HAM_0005027  ISIC_0032329  akiec      histo  85.0  female
# 9818  HAM_0005924  ISIC_0030953  akiec      histo  80.0  female
# ...           ...           ...    ...        ...   ...     ...
# 2323  HAM_0001920  ISIC_0031901   vasc      histo  55.0    male
# 2369  HAM_0006946  ISIC_0032866   vasc      histo  55.0  female
# 2448  HAM_0006447  ISIC_0031276   vasc  consensus  75.0    male
# 2378  HAM_0007097  ISIC_0034214   vasc      histo  60.0    male
# 2394  HAM_0007020  ISIC_0031719   vasc  consensus  75.0  female
#
#          localization        dataset  label  \
# 9812             back      rosendahl      0
# 9914             face      rosendahl      0
# 9797  upper extremity      rosendahl      0
# 9704             back      rosendahl      0
# 9818  upper extremity      rosendahl      0
# ...               ...            ...    ...
# 2323             back   vidir_modern      6
# 2369             back   vidir_modern      6
# 2448          abdomen  vidir_molemax      6
# 2378            trunk   vidir_modern      6
# 2394             hand   vidir_modern      6
#
#                                            image_paths
# 9812  /content/HAM10000_images_part_2/ISIC_0029371.jpg
# 9914  /content/HAM10000_images_part_2/ISIC_0029900.jpg
# 9797  /content/HAM10000_images_part_1/ISIC_0027753.jpg
# 9704  /content/HAM10000_images_part_2/ISIC_0032329.jpg
# 9818  /content/HAM10000_images_part_2/ISIC_0030953.jpg
# ...                                                ...
# 2323  /content/HAM10000_images_part_2/ISIC_0031901.jpg
# 2369  /content/HAM10000_images_part_2/ISIC_0032866.jpg
# 2448  /content/HAM10000_images_part_2/ISIC_0031276.jpg
# 2378  /content/HAM10000_images_part_2/ISIC_0034214.jpg
# 2394  /content/HAM10000_images_part_2/ISIC_0031719.jpg
#
# [7000 rows x 10 columns]

# %%
#turn images to array and add as a new column 
trainset_balanced['image'] = trainset_balanced['image_paths'].map(lambda x: np.asarray(Image.open(x).resize((im_size,im_size))))

# %%
ts_balanced['image'] = ts_balanced['image_paths'].map(lambda x: np.asarray(Image.open(x).resize((im_size,im_size))))

ts_balanced
# Out:
#         image_id     dx  label  \
# 0   ISIC_0026765  akiec      0
# 1   ISIC_0033151  akiec      0
# 2   ISIC_0029315  akiec      0
# 3   ISIC_0025712  akiec      0
# 4   ISIC_0032203  akiec      0
# ..           ...    ...    ...
# 70  ISIC_0027790   vasc      6
# 71  ISIC_0024662   vasc      6
# 72  ISIC_0032240   vasc      6
# 73  ISIC_0032538   vasc      6
# 74  ISIC_0032692   vasc      6
#
#                                          image_paths  \
# 0   /content/HAM10000_images_part_1/ISIC_0026765.jpg
# 1   /content/HAM10000_images_part_2/ISIC_0033151.jpg
# 2   /content/HAM10000_images_part_2/ISIC_0029315.jpg
# 3   /content/HAM10000_images_part_1/ISIC_0025712.jpg
# 4   /content/HAM10000_images_part_2/ISIC_0032203.jpg
# ..                                               ...
# 70  /content/HAM10000_images_part_1/ISIC_0027790.jpg
# 71  /content/HAM10000_images_part_1/ISIC_0024662.jpg
# 72  /content/HAM10000_images_part_2/ISIC_0032240.jpg
# 73  /content/HAM10000_images_part_2/ISIC_0032538.jpg
# 74  /content/HAM10000_images_part_2/ISIC_0032692.jpg
#
#                                                 image
# 0   [[[209, 172, 163], [212, 177, 166], [213, 178,...
# 1   [[[137, 97, 102], [138, 96, 105], [138, 96, 10...
# 2   [[[177, 149, 148], [176, 151, 150], [175, 152,...
# 3   [[[185, 134, 143], [177, 123, 130], [177, 121,...
# 4   [[[183, 163, 163], [181, 160, 159], [174, 154,...
# ..                                                ...
# 70  [[[172, 123, 135], [172, 124, 133], [172, 124,...
# 71  [[[236, 136, 155], [238, 132, 156], [234, 127,...
# 72  [[[203, 171, 186], [202, 171, 186], [202, 174,...
# 73  [[[28, 22, 23], [28, 24, 24], [35, 25, 27], [4...
# 74  [[[217, 173, 180], [219, 174, 181], [223, 175,...
#
# [525 rows x 5 columns]

# %%
X_trainset = np.asarray(trainset_balanced['image'].tolist())
X_trainset = X_trainset/255. 
Y_trainset = trainset_balanced['label']
Y_dx_trainset = to_categorical(Y_trainset, num_classes=7)

# %%
X_ts = np.asarray(ts_balanced['image'].tolist())
X_ts = X_ts/255. 
Y_ts = ts_balanced['label']
Y_dx_ts = to_categorical(Y_ts, num_classes=7)

# %%
#train/validation split - 70/30 split

x_train, x_val, y_train, y_val = train_test_split(X_trainset, Y_dx_trainset, test_size=0.30, random_state=29)

# %%
#GPU
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
#model

img_rows, img_cols = 224, 224 

vgg_mod = vgg16.VGG16(weights = 'imagenet', 
                 include_top = False, 
                 input_shape = (img_rows, img_cols, 3))
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58889256/58889256 [==============================] - 0s 0us/step

# %%
#freeze last 4 layers
for layer in vgg_mod.layers:
    layer.trainable = False

# %%
for (i,layer) in enumerate(vgg_mod.layers):
    print(str(i) + " "+ layer.__class__.__name__, layer.trainable)
# Out:
# 0 InputLayer False
# 1 Conv2D False
# 2 Conv2D False
# 3 MaxPooling2D False
# 4 Conv2D False
# 5 Conv2D False
# 6 MaxPooling2D False
# 7 Conv2D False
# 8 Conv2D False
# 9 Conv2D False
# 10 MaxPooling2D False
# 11 Conv2D False
# 12 Conv2D False
# 13 Conv2D False
# 14 MaxPooling2D False
# 15 Conv2D False
# 16 Conv2D False
# 17 Conv2D False
# 18 MaxPooling2D False

# %%
#top layers replaced by our own - 7 classes. Other layers used as is and as trained on Imagenet

def lw(bottom_model, num_classes):
    """creates the top or head of the model that will be 
    placed ontop of the bottom layers"""

    top_model = bottom_model.output
    top_model = GlobalAveragePooling2D()(top_model)
    top_model = Dense(1024,activation='relu')(top_model)
    top_model = Dense(1024,activation='relu')(top_model)
    top_model = Dense(512,activation='relu')(top_model)
    top_model = Dense(num_classes,activation='softmax')(top_model)
    return top_model

# %%
num_classes = 7

FC_Head = lw(vgg_mod, num_classes)
model = Model(inputs = vgg_mod.input, outputs = FC_Head)
print(model.summary())
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 224, 224, 3)]     0
#
#  block1_conv1 (Conv2D)       (None, 224, 224, 64)      1792
#
#  block1_conv2 (Conv2D)       (None, 224, 224, 64)      36928
#
#  block1_pool (MaxPooling2D)  (None, 112, 112, 64)      0
#
#  block2_conv1 (Conv2D)       (None, 112, 112, 128)     73856
#
#  block2_conv2 (Conv2D)       (None, 112, 112, 128)     147584
#
#  block2_pool (MaxPooling2D)  (None, 56, 56, 128)       0
#
#  block3_conv1 (Conv2D)       (None, 56, 56, 256)       295168
#
#  block3_conv2 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_conv3 (Conv2D)       (None, 56, 56, 256)       590080
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)       0
#
#  block4_conv1 (Conv2D)       (None, 28, 28, 512)       1180160
#
#  block4_conv2 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_conv3 (Conv2D)       (None, 28, 28, 512)       2359808
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 512)       0
#
#  block5_conv1 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv2 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_conv3 (Conv2D)       (None, 14, 14, 512)       2359808
#
#  block5_pool (MaxPooling2D)  (None, 7, 7, 512)         0
#
#  global_average_pooling2d (G  (None, 512)              0
#  lobalAveragePooling2D)
#
#  dense (Dense)               (None, 1024)              525312
#
#  dense_1 (Dense)             (None, 1024)              1049600
#
#  dense_2 (Dense)             (None, 512)               524800
#
#  dense_3 (Dense)             (None, 7)                 3591
#
# =================================================================
# Total params: 16,817,991
# Trainable params: 2,103,303
# Non-trainable params: 14,714,688
# _________________________________________________________________
# None

# %%
model.compile(optimizer='adam', loss = 'categorical_crossentropy',metrics = ['accuracy'])

# %%
#training

batch_size = 16 
epochs = 75

# %%
mod_fit = model.fit(
    x_train, y_train,
    epochs=epochs,
    batch_size = batch_size,
    validation_data=(x_val, y_val),
    verbose=2)
# Out:
# Epoch 1/75
# 307/307 - 18s - loss: 1.6578 - accuracy: 0.3414 - val_loss: 1.4641 - val_accuracy: 0.4319 - 18s/epoch - 57ms/step
# Epoch 2/75
# 307/307 - 7s - loss: 1.3945 - accuracy: 0.4612 - val_loss: 1.3810 - val_accuracy: 0.4800 - 7s/epoch - 21ms/step
# Epoch 3/75
# 307/307 - 7s - loss: 1.2824 - accuracy: 0.5082 - val_loss: 1.2050 - val_accuracy: 0.5605 - 7s/epoch - 21ms/step
# Epoch 4/75
# 307/307 - 7s - loss: 1.1685 - accuracy: 0.5516 - val_loss: 1.1639 - val_accuracy: 0.5657 - 7s/epoch - 21ms/step
# Epoch 5/75
# 307/307 - 7s - loss: 1.0677 - accuracy: 0.5967 - val_loss: 1.1686 - val_accuracy: 0.5524 - 7s/epoch - 21ms/step
# Epoch 6/75
# 307/307 - 7s - loss: 1.0164 - accuracy: 0.6078 - val_loss: 1.0936 - val_accuracy: 0.5657 - 7s/epoch - 22ms/step
# Epoch 7/75
# 307/307 - 7s - loss: 0.9731 - accuracy: 0.6208 - val_loss: 1.0181 - val_accuracy: 0.6038 - 7s/epoch - 22ms/step
# Epoch 8/75
# 307/307 - 7s - loss: 0.9260 - accuracy: 0.6433 - val_loss: 0.9962 - val_accuracy: 0.5990 - 7s/epoch - 22ms/step
# Epoch 9/75
# 307/307 - 7s - loss: 0.8373 - accuracy: 0.6735 - val_loss: 1.1554 - val_accuracy: 0.5524 - 7s/epoch - 22ms/step
# Epoch 10/75
# 307/307 - 7s - loss: 0.8060 - accuracy: 0.6878 - val_loss: 0.9110 - val_accuracy: 0.6610 - 7s/epoch - 21ms/step
# Epoch 11/75
# 307/307 - 7s - loss: 0.7677 - accuracy: 0.7047 - val_loss: 0.9624 - val_accuracy: 0.6271 - 7s/epoch - 21ms/step
# Epoch 12/75
# 307/307 - 7s - loss: 0.7270 - accuracy: 0.7249 - val_loss: 0.8315 - val_accuracy: 0.6895 - 7s/epoch - 21ms/step
# Epoch 13/75
# 307/307 - 7s - loss: 0.7169 - accuracy: 0.7243 - val_loss: 0.7711 - val_accuracy: 0.7024 - 7s/epoch - 21ms/step
# Epoch 14/75
# 307/307 - 7s - loss: 0.6463 - accuracy: 0.7441 - val_loss: 0.7757 - val_accuracy: 0.7100 - 7s/epoch - 21ms/step
# Epoch 15/75
# 307/307 - 7s - loss: 0.6343 - accuracy: 0.7551 - val_loss: 0.7565 - val_accuracy: 0.7048 - 7s/epoch - 21ms/step
# Epoch 16/75
# 307/307 - 7s - loss: 0.6402 - accuracy: 0.7571 - val_loss: 0.7591 - val_accuracy: 0.7062 - 7s/epoch - 22ms/step
# Epoch 17/75
# 307/307 - 7s - loss: 0.6045 - accuracy: 0.7684 - val_loss: 0.7558 - val_accuracy: 0.7105 - 7s/epoch - 22ms/step
# Epoch 18/75
# 307/307 - 7s - loss: 0.5504 - accuracy: 0.7910 - val_loss: 0.7748 - val_accuracy: 0.7110 - 7s/epoch - 21ms/step
# Epoch 19/75
# 307/307 - 7s - loss: 0.5363 - accuracy: 0.7945 - val_loss: 0.7366 - val_accuracy: 0.7219 - 7s/epoch - 21ms/step
# Epoch 20/75
# 307/307 - 7s - loss: 0.5136 - accuracy: 0.8031 - val_loss: 0.7261 - val_accuracy: 0.7448 - 7s/epoch - 21ms/step
# Epoch 21/75
# 307/307 - 7s - loss: 0.5387 - accuracy: 0.7955 - val_loss: 0.7627 - val_accuracy: 0.7148 - 7s/epoch - 22ms/step
# Epoch 22/75
# 307/307 - 7s - loss: 0.4718 - accuracy: 0.8233 - val_loss: 0.6641 - val_accuracy: 0.7610 - 7s/epoch - 21ms/step
# Epoch 23/75
# 307/307 - 7s - loss: 0.4447 - accuracy: 0.8306 - val_loss: 0.8014 - val_accuracy: 0.7310 - 7s/epoch - 21ms/step
# Epoch 24/75
# 307/307 - 7s - loss: 0.4758 - accuracy: 0.8131 - val_loss: 0.7088 - val_accuracy: 0.7571 - 7s/epoch - 21ms/step
# Epoch 25/75
# 307/307 - 7s - loss: 0.4196 - accuracy: 0.8380 - val_loss: 0.6406 - val_accuracy: 0.7767 - 7s/epoch - 21ms/step
# Epoch 26/75
# 307/307 - 7s - loss: 0.4197 - accuracy: 0.8353 - val_loss: 0.7119 - val_accuracy: 0.7686 - 7s/epoch - 21ms/step
# Epoch 27/75
# 307/307 - 7s - loss: 0.3655 - accuracy: 0.8612 - val_loss: 0.6192 - val_accuracy: 0.7910 - 7s/epoch - 21ms/step
# Epoch 28/75
# 307/307 - 7s - loss: 0.3532 - accuracy: 0.8690 - val_loss: 0.7040 - val_accuracy: 0.7833 - 7s/epoch - 21ms/step
# Epoch 29/75
# 307/307 - 7s - loss: 0.3809 - accuracy: 0.8582 - val_loss: 0.6809 - val_accuracy: 0.7795 - 7s/epoch - 21ms/step
# Epoch 30/75
# 307/307 - 7s - loss: 0.3464 - accuracy: 0.8704 - val_loss: 0.7293 - val_accuracy: 0.8019 - 7s/epoch - 21ms/step
# Epoch 31/75
# 307/307 - 7s - loss: 0.3396 - accuracy: 0.8759 - val_loss: 0.6857 - val_accuracy: 0.8214 - 7s/epoch - 21ms/step
# Epoch 32/75
# 307/307 - 7s - loss: 0.3214 - accuracy: 0.8771 - val_loss: 0.8479 - val_accuracy: 0.7638 - 7s/epoch - 21ms/step
# Epoch 33/75
# 307/307 - 7s - loss: 0.3401 - accuracy: 0.8765 - val_loss: 0.6150 - val_accuracy: 0.8205 - 7s/epoch - 21ms/step
# Epoch 34/75
# 307/307 - 7s - loss: 0.2982 - accuracy: 0.8908 - val_loss: 0.7145 - val_accuracy: 0.7838 - 7s/epoch - 21ms/step
# Epoch 35/75
# 307/307 - 7s - loss: 0.3224 - accuracy: 0.8818 - val_loss: 0.7385 - val_accuracy: 0.7910 - 7s/epoch - 21ms/step
# Epoch 36/75
# 307/307 - 7s - loss: 0.2627 - accuracy: 0.9020 - val_loss: 0.6473 - val_accuracy: 0.8133 - 7s/epoch - 21ms/step
# Epoch 37/75
# 307/307 - 7s - loss: 0.2582 - accuracy: 0.9100 - val_loss: 0.7467 - val_accuracy: 0.8157 - 7s/epoch - 21ms/step
# Epoch 38/75
# 307/307 - 7s - loss: 0.2036 - accuracy: 0.9257 - val_loss: 0.7161 - val_accuracy: 0.8114 - 7s/epoch - 21ms/step
# Epoch 39/75
# 307/307 - 7s - loss: 0.2900 - accuracy: 0.9014 - val_loss: 0.6812 - val_accuracy: 0.7900 - 7s/epoch - 21ms/step
# Epoch 40/75
# 307/307 - 7s - loss: 0.2102 - accuracy: 0.9210 - val_loss: 0.6621 - val_accuracy: 0.8362 - 7s/epoch - 21ms/step
# Epoch 41/75
# 307/307 - 7s - loss: 0.1828 - accuracy: 0.9322 - val_loss: 0.7202 - val_accuracy: 0.8352 - 7s/epoch - 21ms/step
# Epoch 42/75
# 307/307 - 7s - loss: 0.2311 - accuracy: 0.9182 - val_loss: 0.7546 - val_accuracy: 0.8319 - 7s/epoch - 21ms/step
# Epoch 43/75
# 307/307 - 7s - loss: 0.2934 - accuracy: 0.8990 - val_loss: 0.6457 - val_accuracy: 0.8229 - 7s/epoch - 21ms/step
# Epoch 44/75
# 307/307 - 7s - loss: 0.1695 - accuracy: 0.9382 - val_loss: 0.7095 - val_accuracy: 0.8286 - 7s/epoch - 21ms/step
# Epoch 45/75
# 307/307 - 7s - loss: 0.1532 - accuracy: 0.9484 - val_loss: 0.8218 - val_accuracy: 0.8229 - 7s/epoch - 21ms/step
# Epoch 46/75
# 307/307 - 7s - loss: 0.1514 - accuracy: 0.9416 - val_loss: 0.8465 - val_accuracy: 0.8019 - 7s/epoch - 21ms/step
# Epoch 47/75
# 307/307 - 7s - loss: 0.2350 - accuracy: 0.9180 - val_loss: 0.7854 - val_accuracy: 0.8257 - 7s/epoch - 21ms/step
# Epoch 48/75
# 307/307 - 7s - loss: 0.1491 - accuracy: 0.9445 - val_loss: 0.8134 - val_accuracy: 0.8343 - 7s/epoch - 21ms/step
# Epoch 49/75
# 307/307 - 7s - loss: 0.1740 - accuracy: 0.9347 - val_loss: 0.8036 - val_accuracy: 0.8429 - 7s/epoch - 21ms/step
# Epoch 50/75
# 307/307 - 7s - loss: 0.1707 - accuracy: 0.9355 - val_loss: 0.8000 - val_accuracy: 0.8310 - 7s/epoch - 21ms/step
# Epoch 51/75
# 307/307 - 7s - loss: 0.1362 - accuracy: 0.9508 - val_loss: 0.8314 - val_accuracy: 0.8338 - 7s/epoch - 21ms/step
# Epoch 52/75
# 307/307 - 7s - loss: 0.1502 - accuracy: 0.9459 - val_loss: 0.8350 - val_accuracy: 0.8262 - 7s/epoch - 21ms/step
# Epoch 53/75
# 307/307 - 7s - loss: 0.1540 - accuracy: 0.9453 - val_loss: 0.8963 - val_accuracy: 0.8157 - 7s/epoch - 21ms/step
# Epoch 54/75
# 307/307 - 7s - loss: 0.1610 - accuracy: 0.9437 - val_loss: 0.8492 - val_accuracy: 0.8371 - 7s/epoch - 21ms/step
# Epoch 55/75
# 307/307 - 7s - loss: 0.1599 - accuracy: 0.9453 - val_loss: 0.8595 - val_accuracy: 0.8124 - 7s/epoch - 21ms/step
# Epoch 56/75
# 307/307 - 7s - loss: 0.1275 - accuracy: 0.9539 - val_loss: 0.8674 - val_accuracy: 0.8295 - 7s/epoch - 21ms/step
# Epoch 57/75
# 307/307 - 7s - loss: 0.1350 - accuracy: 0.9520 - val_loss: 0.8166 - val_accuracy: 0.8471 - 7s/epoch - 21ms/step
# Epoch 58/75
# 307/307 - 7s - loss: 0.0863 - accuracy: 0.9706 - val_loss: 0.7882 - val_accuracy: 0.8562 - 7s/epoch - 21ms/step
# Epoch 59/75
# 307/307 - 7s - loss: 0.0824 - accuracy: 0.9698 - val_loss: 0.7666 - val_accuracy: 0.8438 - 7s/epoch - 21ms/step
# Epoch 60/75
# 307/307 - 7s - loss: 0.1895 - accuracy: 0.9361 - val_loss: 0.9416 - val_accuracy: 0.8529 - 7s/epoch - 21ms/step
# Epoch 61/75
# 307/307 - 7s - loss: 0.1066 - accuracy: 0.9663 - val_loss: 0.8264 - val_accuracy: 0.8424 - 7s/epoch - 21ms/step
# Epoch 62/75
# 307/307 - 7s - loss: 0.0627 - accuracy: 0.9784 - val_loss: 0.9451 - val_accuracy: 0.8500 - 7s/epoch - 21ms/step
# Epoch 63/75
# 307/307 - 7s - loss: 0.0789 - accuracy: 0.9735 - val_loss: 1.0101 - val_accuracy: 0.8438 - 7s/epoch - 21ms/step
# Epoch 64/75
# 307/307 - 7s - loss: 0.2437 - accuracy: 0.9218 - val_loss: 0.7925 - val_accuracy: 0.8657 - 7s/epoch - 21ms/step
# Epoch 65/75
# 307/307 - 7s - loss: 0.0630 - accuracy: 0.9786 - val_loss: 0.8052 - val_accuracy: 0.8567 - 7s/epoch - 21ms/step
# Epoch 66/75
# 307/307 - 7s - loss: 0.0797 - accuracy: 0.9704 - val_loss: 0.8944 - val_accuracy: 0.8500 - 7s/epoch - 21ms/step
# Epoch 67/75
# 307/307 - 7s - loss: 0.1612 - accuracy: 0.9451 - val_loss: 0.9364 - val_accuracy: 0.8081 - 7s/epoch - 21ms/step
# Epoch 68/75
# 307/307 - 7s - loss: 0.0881 - accuracy: 0.9694 - val_loss: 0.8578 - val_accuracy: 0.8605 - 7s/epoch - 21ms/step
# Epoch 69/75
# 307/307 - 7s - loss: 0.0407 - accuracy: 0.9869 - val_loss: 0.9256 - val_accuracy: 0.8648 - 7s/epoch - 21ms/step
# Epoch 70/75
# 307/307 - 7s - loss: 0.1029 - accuracy: 0.9629 - val_loss: 0.9628 - val_accuracy: 0.8548 - 7s/epoch - 21ms/step
# Epoch 71/75
# 307/307 - 7s - loss: 0.0806 - accuracy: 0.9714 - val_loss: 0.9549 - val_accuracy: 0.8490 - 7s/epoch - 21ms/step
# Epoch 72/75
# 307/307 - 7s - loss: 0.1578 - accuracy: 0.9473 - val_loss: 0.8575 - val_accuracy: 0.8262 - 7s/epoch - 22ms/step
# Epoch 73/75
# 307/307 - 7s - loss: 0.0678 - accuracy: 0.9776 - val_loss: 0.9902 - val_accuracy: 0.8433 - 7s/epoch - 21ms/step
# Epoch 74/75
# 307/307 - 7s - loss: 0.0604 - accuracy: 0.9820 - val_loss: 0.8366 - val_accuracy: 0.8710 - 7s/epoch - 21ms/step
# Epoch 75/75
# 307/307 - 7s - loss: 0.0309 - accuracy: 0.9912 - val_loss: 0.9934 - val_accuracy: 0.8381 - 7s/epoch - 21ms/step

# %%
mod_acc_val = model.evaluate(x_val, y_val)
print('Validation accuracy:', mod_acc_val[1])
# Out:
# 66/66 [==============================] - 2s 26ms/step - loss: 0.9936 - accuracy: 0.8376
# Validation accuracy: 0.8376190662384033

# %%
loss = mod_fit.history['loss']
val_loss = mod_fit.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
acc = mod_fit.history['accuracy']
val_acc = mod_fit.history['val_accuracy']
plt.plot(epochs, acc, 'y', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.show()

# %%
y_pred = model.predict(X_ts)
# Out:
# 17/17 [==============================] - 1s 45ms/step

# %%
#one hot encoding --> probs from softmax to 1 and 0
y_pred_classes = np.argmax(y_pred, axis = 1)

# %%
y_true = np.argmax(Y_dx_ts, axis = 1)

# %%
cm = confusion_matrix(y_true, y_pred_classes)
fig, ax = plt.subplots(figsize=(10,10))
sns.set(font_scale=1.6)
sns.heatmap(cm, annot=True, linewidths=.5, ax=ax)

# %%
incorr_fraction = 1 - np.diag(cm) / np.sum(cm, axis=1)

incorr_fraction = incorr_fraction.tolist()

incorr_fraction = [round(item, 2) for item in incorr_fraction]

incorr_fraction
# Out:
# [0.63, 0.65, 0.48, 0.89, 0.45, 0.49, 0.41]

# %%
#percent misclassified per dx
def addlabels(x,y):
    for i in range(len(x)):
        plt.text(i, y[i], y[i], ha = 'center')
  
if __name__ == '__main__':
  plt.bar(np.arange(7), incorr_fraction)
  addlabels(np.arange(7), incorr_fraction)
  plt.title("Fraction Misclassified per Diagnosis Label")
  plt.xlabel('True Label')
  plt.ylabel('Fraction of incorrect predictions')

# %%
mod_acc_test = model.evaluate(X_ts, Y_dx_ts)
print('Test accuracy:', mod_acc_test[1])
# Out:
# 17/17 [==============================] - 0s 26ms/step - loss: 5.3368 - accuracy: 0.4267
# Test accuracy: 0.4266666769981384

# %%
#reference
#https://www.youtube.com/watch?v=Fxy6WTnUIww
#https://keras.io/api/layers/core_layers/dense/
#https://keras.io/api/models/model/
#https://www.educba.com/keras-fit/
#https://www.geeksforgeeks.org/adding-value-labels-on-a-matplotlib-bar-chart/
#https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.transpose.html
#https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.from_dict.html
#https://www.geeksforgeeks.org/drop-rows-from-the-dataframe-based-on-certain-condition-applied-on-a-column/
#https://sparkbyexamples.com/pandas/conver-pandas-column-to-list/
#https://datascience.stackexchange.com/questions/37227/how-to-remove-rows-from-a-dataframe-that-are-identical-to-another-dataframe

# %%
0 - 0.36
1 - 0.35
2 - 0.52
3 - 0.11
4 - 0.55
5 - 0.51
6 - 0.59
