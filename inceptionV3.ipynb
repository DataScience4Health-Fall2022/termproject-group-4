# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !unzip -d ./dataverse_files /content/drive/MyDrive/dataverse_files.zip

# !unzip -d ./dataverse_files/HAM10000_images_part_1 /content/dataverse_files/HAM10000_images_part_1.zip
# !unzip -d ./dataverse_files/HAM10000_images_part_2 /content/dataverse_files/HAM10000_images_part_2.zip
# !unzip -d ./dataverse_files /content/dataverse_files/ISIC2018_Task3_Test_Images.zip

# %% [markdown]
# # 1. Preprocessing

# %%
import pandas as pd
import os
import shutil

# %%
# move training and test images into folders

# create train and test folder
if not os.path.exists('dataverse_files/train'):
    os.mkdir('dataverse_files/train')
    
if not os.path.exists('dataverse_files/test'):
    os.mkdir('dataverse_files/test')
    
for img_name in os.listdir('dataverse_files/HAM10000_images_part_1/'):
    src_path = os.path.join('dataverse_files/HAM10000_images_part_1', img_name)
    tgt_path = 'dataverse_files/train'
    shutil.move(src_path, tgt_path)
    
for img_name in os.listdir('dataverse_files/HAM10000_images_part_2/'):
    src_path = os.path.join('dataverse_files/HAM10000_images_part_2', img_name)
    tgt_path = 'dataverse_files/train'
    shutil.move(src_path, tgt_path)

for img_name in os.listdir('dataverse_files/ISIC2018_Task3_Test_Images/'):
    src_path = os.path.join('dataverse_files/ISIC2018_Task3_Test_Images', img_name)
    tgt_path = 'dataverse_files/test'
    shutil.move(src_path, tgt_path)

# %%
train_df = pd.read_csv('dataverse_files/HAM10000_metadata')
test_df = pd.read_csv('dataverse_files/ISIC2018_Task3_Test_NatureMedicine_AI_Interaction_Benefit.csv')

# %%
# convert to numerical representation
from sklearn.preprocessing import LabelEncoder

lb = LabelEncoder()
lb.fit_transform(train_df['dx'])
cls2lbl = {cls: idx for idx, cls in enumerate(lb.classes_)}
lbl2cls = {idx: cls for idx, cls in enumerate(lb.classes_)}
train_df['label'] = [cls2lbl[cls] for cls in train_df['dx']]

# %%
# extract label in test set
test_df['label'] = test_df[['prob_h_dx_akiec', 
                            'prob_h_dx_bcc',
                            'prob_h_dx_bkl', 
                            'prob_h_dx_df', 
                            'prob_h_dx_mel', 
                            'prob_h_dx_nv',
                            'prob_h_dx_vasc']].values.argmax(axis=1)

# %% [markdown]
# # 2. Data loader

# %%
from PIL import Image
import torch
from torch.utils.data import Dataset, DataLoader
from torchvision.transforms import ToTensor, RandomAffine, Resize, CenterCrop, Normalize

class MyDataset(Dataset):
    def __init__(self, train=True):
        self.meta = train_df if train else test_df
        self.root_dir = 'dataverse_files/train' if train else 'dataverse_files/test'
    def __len__(self):
        return len(self.meta)
    def __getitem__(self, idx):
        img_name = self.meta['image_id'].iloc[idx] + '.jpg'
        img_path = os.path.join(self.root_dir, img_name)

        image = Image.open(img_path)
        image = Resize((299, 299))(image)
        image = CenterCrop(299)(image)
        # image = RandomAffine(degrees=(-10, 10), translate=(0.05, 0.1), scale=(0.9, 1.1))(image)
        image = ToTensor()(image)
        image = Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])(image)
        
        label = self.meta['label'].iloc[idx]
        return image, label

train_dataset = MyDataset(train=True)
test_dataset = MyDataset(train=False)

train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=100, shuffle=False)

# %% [markdown]
# # 3. Models

# %%
import torch.nn as nn
from torchvision.models import inception_v3

model = inception_v3()
model.fc = nn.Linear(in_features=2048, out_features=len(lbl2cls))
model
# Out:
# Inception3(
#   (Conv2d_1a_3x3): BasicConv2d(
#     (conv): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2a_3x3): BasicConv2d(
#     (conv): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_2b_3x3): BasicConv2d(
#     (conv): Conv2d(32, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#     (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool1): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Conv2d_3b_1x1): BasicConv2d(
#     (conv): Conv2d(64, 80, kernel_size=(1, 1), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(80, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (Conv2d_4a_3x3): BasicConv2d(
#     (conv): Conv2d(80, 192, kernel_size=(3, 3), stride=(1, 1), bias=False)
#     (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (maxpool2): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (Mixed_5b): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(192, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(192, 32, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(32, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5c): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(256, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_5d): InceptionA(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_1): BasicConv2d(
#       (conv): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(48, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch5x5_2): BasicConv2d(
#       (conv): Conv2d(48, 64, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6a): InceptionB(
#     (branch3x3): BasicConv2d(
#       (conv): Conv2d(288, 384, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(288, 64, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(64, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(64, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3): BasicConv2d(
#       (conv): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(96, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6b): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(128, 128, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(128, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6c): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6d): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 160, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(160, 160, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(160, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(160, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_6e): InceptionC(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7dbl_5): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (AuxLogits): InceptionAux(
#     (conv0): BasicConv2d(
#       (conv): Conv2d(768, 128, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(128, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (conv1): BasicConv2d(
#       (conv): Conv2d(128, 768, kernel_size=(5, 5), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(768, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (fc): Linear(in_features=768, out_features=1000, bias=True)
#   )
#   (Mixed_7a): InceptionD(
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2): BasicConv2d(
#       (conv): Conv2d(192, 320, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_1): BasicConv2d(
#       (conv): Conv2d(768, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_2): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(1, 7), stride=(1, 1), padding=(0, 3), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_3): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(7, 1), stride=(1, 1), padding=(3, 0), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch7x7x3_4): BasicConv2d(
#       (conv): Conv2d(192, 192, kernel_size=(3, 3), stride=(2, 2), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7b): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(1280, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(1280, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(1280, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(1280, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (Mixed_7c): InceptionE(
#     (branch1x1): BasicConv2d(
#       (conv): Conv2d(2048, 320, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(320, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_1): BasicConv2d(
#       (conv): Conv2d(2048, 384, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3_2b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_1): BasicConv2d(
#       (conv): Conv2d(2048, 448, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(448, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_2): BasicConv2d(
#       (conv): Conv2d(448, 384, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3a): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(1, 3), stride=(1, 1), padding=(0, 1), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch3x3dbl_3b): BasicConv2d(
#       (conv): Conv2d(384, 384, kernel_size=(3, 1), stride=(1, 1), padding=(1, 0), bias=False)
#       (bn): BatchNorm2d(384, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (branch_pool): BasicConv2d(
#       (conv): Conv2d(2048, 192, kernel_size=(1, 1), stride=(1, 1), bias=False)
#       (bn): BatchNorm2d(192, eps=0.001, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (dropout): Dropout(p=0.5, inplace=False)
#   (fc): Linear(in_features=2048, out_features=7, bias=True)
# )

# %% [markdown]
# # 4. Train

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
model = model.to(device)

n_epochs = 10
lr = 0.001
optimizer = torch.optim.Adam(params=model.parameters(), lr=lr)
loss_func = torch.nn.CrossEntropyLoss()
best_test_acc = 0

for i in range(n_epochs):
    for idx, (image, label) in enumerate(train_loader):
        image = image.to(device)
        label = label.to(device)
        
        y_pred = model(image)[0]
        loss = loss_func(y_pred, label)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        if (idx + 1) % 10 == 0:
            print(f'Iteration: {i+1}/{n_epochs}, Step: {idx+1}/{len(train_loader)}, Loss: {loss.item():.4f}')
    
    model.eval()
    with torch.no_grad():
        n_instances = len(test_loader)
        n_correct = 0
        for image, label in test_loader:
            image = image.to(device)
            label = label.to(device)
            
            y_pred = model(image)
            pred = torch.argmax(y_pred, dim=1)
            n_correct += (pred == label).sum().item()
        test_acc = n_correct / n_instances
        print(f'Iteration: {i+1}/{n_epochs}, Test accuracy: {test_acc:.4f}')
        
        if test_acc > best_test_acc:
            best_test_acc = test_acc
            torch.save(model, 'best_model.pth')
        
    model.train()
    
print(f'Best test accuracy: {best_test_acc:.4f}')
# Out:
# Iteration: 1/10, Step: 10/313, Loss: 1.8915
# Iteration: 1/10, Step: 20/313, Loss: 1.2862
# Iteration: 1/10, Step: 30/313, Loss: 0.9231
# Iteration: 1/10, Step: 40/313, Loss: 0.7849
# Iteration: 1/10, Step: 50/313, Loss: 1.1240
# Iteration: 1/10, Step: 60/313, Loss: 1.1732
# Iteration: 1/10, Step: 70/313, Loss: 1.1472
# Iteration: 1/10, Step: 80/313, Loss: 0.9072
# Iteration: 1/10, Step: 90/313, Loss: 0.7213
# Iteration: 1/10, Step: 100/313, Loss: 0.9384
# Iteration: 1/10, Step: 110/313, Loss: 0.8257
# Iteration: 1/10, Step: 120/313, Loss: 0.6709
# Iteration: 1/10, Step: 130/313, Loss: 0.6229
# Iteration: 1/10, Step: 140/313, Loss: 0.9555
# Iteration: 1/10, Step: 150/313, Loss: 0.8267
# Iteration: 1/10, Step: 160/313, Loss: 0.6357
# Iteration: 1/10, Step: 170/313, Loss: 0.5327
# Iteration: 1/10, Step: 180/313, Loss: 0.6272
# Iteration: 1/10, Step: 190/313, Loss: 0.9773
# Iteration: 1/10, Step: 200/313, Loss: 0.8413
# Iteration: 1/10, Step: 210/313, Loss: 0.8176
# Iteration: 1/10, Step: 220/313, Loss: 0.7755
# Iteration: 1/10, Step: 230/313, Loss: 0.7466
# Iteration: 1/10, Step: 240/313, Loss: 0.7213
# Iteration: 1/10, Step: 250/313, Loss: 0.4921
# Iteration: 1/10, Step: 260/313, Loss: 0.5616
# Iteration: 1/10, Step: 270/313, Loss: 0.6440
# Iteration: 1/10, Step: 280/313, Loss: 0.9370
# Iteration: 1/10, Step: 290/313, Loss: 0.8590
# Iteration: 1/10, Step: 300/313, Loss: 1.0677
# Iteration: 1/10, Step: 310/313, Loss: 0.9996
# Iteration: 1/10, Test accuracy: 49.3947
# Iteration: 2/10, Step: 10/313, Loss: 0.9325
# Iteration: 2/10, Step: 20/313, Loss: 0.7979
# Iteration: 2/10, Step: 30/313, Loss: 0.9405
# Iteration: 2/10, Step: 40/313, Loss: 0.6858
# Iteration: 2/10, Step: 50/313, Loss: 0.8593
# Iteration: 2/10, Step: 60/313, Loss: 0.7192
# Iteration: 2/10, Step: 70/313, Loss: 0.8487
# Iteration: 2/10, Step: 80/313, Loss: 0.5985
# Iteration: 2/10, Step: 90/313, Loss: 0.6109
# Iteration: 2/10, Step: 100/313, Loss: 0.8274
# Iteration: 2/10, Step: 110/313, Loss: 1.1609
# Iteration: 2/10, Step: 120/313, Loss: 1.0410
# Iteration: 2/10, Step: 130/313, Loss: 0.8194
# Iteration: 2/10, Step: 140/313, Loss: 0.7533
# Iteration: 2/10, Step: 150/313, Loss: 0.5840
# Iteration: 2/10, Step: 160/313, Loss: 0.7004
# Iteration: 2/10, Step: 170/313, Loss: 0.5547
# Iteration: 2/10, Step: 180/313, Loss: 1.1603
# Iteration: 2/10, Step: 190/313, Loss: 0.8793
# Iteration: 2/10, Step: 200/313, Loss: 0.7670
# Iteration: 2/10, Step: 210/313, Loss: 0.6828
# Iteration: 2/10, Step: 220/313, Loss: 0.6649
# Iteration: 2/10, Step: 230/313, Loss: 0.7375
# Iteration: 2/10, Step: 240/313, Loss: 0.6986
# Iteration: 2/10, Step: 250/313, Loss: 0.8254
# Iteration: 2/10, Step: 260/313, Loss: 0.9049
# Iteration: 2/10, Step: 270/313, Loss: 0.6822
# Iteration: 2/10, Step: 280/313, Loss: 0.8366
# Iteration: 2/10, Step: 290/313, Loss: 1.0432
# Iteration: 2/10, Step: 300/313, Loss: 0.8828
# Iteration: 2/10, Step: 310/313, Loss: 0.7242
# Iteration: 2/10, Test accuracy: 48.9737
# Iteration: 3/10, Step: 10/313, Loss: 1.0817
# Iteration: 3/10, Step: 20/313, Loss: 0.7674
# Iteration: 3/10, Step: 30/313, Loss: 0.6464
# Iteration: 3/10, Step: 40/313, Loss: 0.5927
# Iteration: 3/10, Step: 50/313, Loss: 0.7054
# Iteration: 3/10, Step: 60/313, Loss: 0.9285
# Iteration: 3/10, Step: 70/313, Loss: 0.6478
# Iteration: 3/10, Step: 80/313, Loss: 1.1217
# Iteration: 3/10, Step: 90/313, Loss: 0.7813
# Iteration: 3/10, Step: 100/313, Loss: 0.5949
# Iteration: 3/10, Step: 110/313, Loss: 0.8073
# Iteration: 3/10, Step: 120/313, Loss: 0.6333
# Iteration: 3/10, Step: 130/313, Loss: 0.7407
# Iteration: 3/10, Step: 140/313, Loss: 0.9085
# Iteration: 3/10, Step: 150/313, Loss: 0.9314
# Iteration: 3/10, Step: 160/313, Loss: 0.7070
# Iteration: 3/10, Step: 170/313, Loss: 0.7564
# Iteration: 3/10, Step: 180/313, Loss: 0.7956
# Iteration: 3/10, Step: 190/313, Loss: 0.6509
# Iteration: 3/10, Step: 200/313, Loss: 1.0072
# Iteration: 3/10, Step: 210/313, Loss: 0.7239
# Iteration: 3/10, Step: 220/313, Loss: 0.8363
# Iteration: 3/10, Step: 230/313, Loss: 0.5838
# Iteration: 3/10, Step: 240/313, Loss: 0.5998
# Iteration: 3/10, Step: 250/313, Loss: 0.9508
# Iteration: 3/10, Step: 260/313, Loss: 1.1437
# Iteration: 3/10, Step: 270/313, Loss: 0.5366
# Iteration: 3/10, Step: 280/313, Loss: 0.5402
# Iteration: 3/10, Step: 290/313, Loss: 0.8411
# Iteration: 3/10, Step: 300/313, Loss: 0.5864
# Iteration: 3/10, Step: 310/313, Loss: 0.6907
# Iteration: 3/10, Test accuracy: 48.1316
# Iteration: 4/10, Step: 10/313, Loss: 0.6436
# Iteration: 4/10, Step: 20/313, Loss: 0.6622
# Iteration: 4/10, Step: 30/313, Loss: 0.5704
# Iteration: 4/10, Step: 40/313, Loss: 0.6557
# Iteration: 4/10, Step: 50/313, Loss: 0.6848
# Iteration: 4/10, Step: 60/313, Loss: 0.6832
# Iteration: 4/10, Step: 70/313, Loss: 0.8121
# Iteration: 4/10, Step: 80/313, Loss: 0.6281
# Iteration: 4/10, Step: 90/313, Loss: 0.8872
# Iteration: 4/10, Step: 100/313, Loss: 0.6328
# Iteration: 4/10, Step: 110/313, Loss: 0.4710
# Iteration: 4/10, Step: 120/313, Loss: 0.7777
# Iteration: 4/10, Step: 130/313, Loss: 0.5662
# Iteration: 4/10, Step: 140/313, Loss: 0.5758
# Iteration: 4/10, Step: 150/313, Loss: 0.5296
# Iteration: 4/10, Step: 160/313, Loss: 0.4870
# Iteration: 4/10, Step: 170/313, Loss: 0.5527
# Iteration: 4/10, Step: 180/313, Loss: 0.5201
# Iteration: 4/10, Step: 190/313, Loss: 0.4710
# Iteration: 4/10, Step: 200/313, Loss: 0.7759
# Iteration: 4/10, Step: 210/313, Loss: 0.9789
# Iteration: 4/10, Step: 220/313, Loss: 0.9022
# Iteration: 4/10, Step: 230/313, Loss: 0.5882
# Iteration: 4/10, Step: 240/313, Loss: 0.8998
# Iteration: 4/10, Step: 250/313, Loss: 0.6939
# Iteration: 4/10, Step: 260/313, Loss: 1.0098
# Iteration: 4/10, Step: 270/313, Loss: 0.7325
# Iteration: 4/10, Step: 280/313, Loss: 0.6490
# Iteration: 4/10, Step: 290/313, Loss: 0.7527
# Iteration: 4/10, Step: 300/313, Loss: 0.5457
# Iteration: 4/10, Step: 310/313, Loss: 0.7995
# Iteration: 4/10, Test accuracy: 49.4474
# Iteration: 5/10, Step: 10/313, Loss: 0.8843
# Iteration: 5/10, Step: 20/313, Loss: 0.8826
# Iteration: 5/10, Step: 30/313, Loss: 0.8777
# Iteration: 5/10, Step: 40/313, Loss: 0.7204
# Iteration: 5/10, Step: 50/313, Loss: 0.8203
# Iteration: 5/10, Step: 60/313, Loss: 0.4427
# Iteration: 5/10, Step: 70/313, Loss: 0.9226
# Iteration: 5/10, Step: 80/313, Loss: 0.6054
# Iteration: 5/10, Step: 90/313, Loss: 0.7019
# Iteration: 5/10, Step: 100/313, Loss: 0.8721
# Iteration: 5/10, Step: 110/313, Loss: 0.5668
# Iteration: 5/10, Step: 120/313, Loss: 0.6671
# Iteration: 5/10, Step: 130/313, Loss: 0.9200
# Iteration: 5/10, Step: 140/313, Loss: 0.5317
# Iteration: 5/10, Step: 150/313, Loss: 0.5211
# Iteration: 5/10, Step: 160/313, Loss: 0.7425
# Iteration: 5/10, Step: 170/313, Loss: 0.4999
# Iteration: 5/10, Step: 180/313, Loss: 0.4423
# Iteration: 5/10, Step: 190/313, Loss: 0.6667
# Iteration: 5/10, Step: 200/313, Loss: 0.4952
# Iteration: 5/10, Step: 210/313, Loss: 0.8003
# Iteration: 5/10, Step: 220/313, Loss: 0.6587
# Iteration: 5/10, Step: 230/313, Loss: 0.8108
# Iteration: 5/10, Step: 240/313, Loss: 0.5874
# Iteration: 5/10, Step: 250/313, Loss: 0.7176
# Iteration: 5/10, Step: 260/313, Loss: 0.4688
# Iteration: 5/10, Step: 270/313, Loss: 0.8555
# Iteration: 5/10, Step: 280/313, Loss: 0.6981
# Iteration: 5/10, Step: 290/313, Loss: 0.4868
# Iteration: 5/10, Step: 300/313, Loss: 0.4121
# Iteration: 5/10, Step: 310/313, Loss: 0.6187
# Iteration: 5/10, Test accuracy: 54.3947
# Iteration: 6/10, Step: 10/313, Loss: 0.4292
# Iteration: 6/10, Step: 20/313, Loss: 0.7434
# Iteration: 6/10, Step: 30/313, Loss: 0.6000
# Iteration: 6/10, Step: 40/313, Loss: 0.4693
# Iteration: 6/10, Step: 50/313, Loss: 0.9669
# Iteration: 6/10, Step: 60/313, Loss: 0.7669
# Iteration: 6/10, Step: 70/313, Loss: 0.7393
# Iteration: 6/10, Step: 80/313, Loss: 0.7283
# Iteration: 6/10, Step: 90/313, Loss: 0.6439
# Iteration: 6/10, Step: 100/313, Loss: 0.6818
# Iteration: 6/10, Step: 110/313, Loss: 0.6400
# Iteration: 6/10, Step: 120/313, Loss: 0.7613
# Iteration: 6/10, Step: 130/313, Loss: 1.2376
# Iteration: 6/10, Step: 140/313, Loss: 0.7313
# Iteration: 6/10, Step: 150/313, Loss: 0.8790
# Iteration: 6/10, Step: 160/313, Loss: 0.7857
# Iteration: 6/10, Step: 170/313, Loss: 0.7571
# Iteration: 6/10, Step: 180/313, Loss: 0.5235
# Iteration: 6/10, Step: 190/313, Loss: 0.5897
# Iteration: 6/10, Step: 200/313, Loss: 0.6354
# Iteration: 6/10, Step: 210/313, Loss: 0.8302
# Iteration: 6/10, Step: 220/313, Loss: 0.3628
# Iteration: 6/10, Step: 230/313, Loss: 0.4260
# Iteration: 6/10, Step: 240/313, Loss: 0.4492
# Iteration: 6/10, Step: 250/313, Loss: 0.5316
# Iteration: 6/10, Step: 260/313, Loss: 0.5280
# Iteration: 6/10, Step: 270/313, Loss: 0.8827
# Iteration: 6/10, Step: 280/313, Loss: 0.5347
# Iteration: 6/10, Step: 290/313, Loss: 0.8668
# Iteration: 6/10, Step: 300/313, Loss: 0.9143
# Iteration: 6/10, Step: 310/313, Loss: 0.7443
# Iteration: 6/10, Test accuracy: 54.0526
# Iteration: 7/10, Step: 10/313, Loss: 0.8064
# Iteration: 7/10, Step: 20/313, Loss: 0.5280
# Iteration: 7/10, Step: 30/313, Loss: 0.5486
# Iteration: 7/10, Step: 40/313, Loss: 0.6688
# Iteration: 7/10, Step: 50/313, Loss: 0.5290
# Iteration: 7/10, Step: 60/313, Loss: 0.3907
# Iteration: 7/10, Step: 70/313, Loss: 0.6095
# Iteration: 7/10, Step: 80/313, Loss: 0.7636
# Iteration: 7/10, Step: 90/313, Loss: 0.6165
# Iteration: 7/10, Step: 100/313, Loss: 0.6168
# Iteration: 7/10, Step: 110/313, Loss: 0.6058
# Iteration: 7/10, Step: 120/313, Loss: 0.7021
# Iteration: 7/10, Step: 130/313, Loss: 0.8779
# Iteration: 7/10, Step: 140/313, Loss: 0.5546
# Iteration: 7/10, Step: 150/313, Loss: 0.6168
# Iteration: 7/10, Step: 160/313, Loss: 0.4791
# Iteration: 7/10, Step: 170/313, Loss: 0.5334
# Iteration: 7/10, Step: 180/313, Loss: 1.0082
# Iteration: 7/10, Step: 190/313, Loss: 0.6389
# Iteration: 7/10, Step: 200/313, Loss: 0.7660
# Iteration: 7/10, Step: 210/313, Loss: 0.5726
# Iteration: 7/10, Step: 220/313, Loss: 0.9958
# Iteration: 7/10, Step: 230/313, Loss: 0.9567
# Iteration: 7/10, Step: 240/313, Loss: 0.7294
# Iteration: 7/10, Step: 250/313, Loss: 1.0629
# Iteration: 7/10, Step: 260/313, Loss: 0.5716
# Iteration: 7/10, Step: 270/313, Loss: 0.7375
# Iteration: 7/10, Step: 280/313, Loss: 0.5613
# Iteration: 7/10, Step: 290/313, Loss: 0.5154
# Iteration: 7/10, Step: 300/313, Loss: 0.6714
# Iteration: 7/10, Step: 310/313, Loss: 0.6073
# Iteration: 7/10, Test accuracy: 58.6842
# Iteration: 8/10, Step: 10/313, Loss: 0.6881
# Iteration: 8/10, Step: 20/313, Loss: 0.4650
# Iteration: 8/10, Step: 30/313, Loss: 0.6041
# Iteration: 8/10, Step: 40/313, Loss: 0.5333
# Iteration: 8/10, Step: 50/313, Loss: 0.6955
# Iteration: 8/10, Step: 60/313, Loss: 0.5917
# Iteration: 8/10, Step: 70/313, Loss: 0.6520
# Iteration: 8/10, Step: 80/313, Loss: 0.6590
# Iteration: 8/10, Step: 90/313, Loss: 0.5887
# Iteration: 8/10, Step: 100/313, Loss: 1.2132
# Iteration: 8/10, Step: 110/313, Loss: 0.5238
# Iteration: 8/10, Step: 120/313, Loss: 0.5611
# Iteration: 8/10, Step: 130/313, Loss: 0.6248
# Iteration: 8/10, Step: 140/313, Loss: 0.5230
# Iteration: 8/10, Step: 150/313, Loss: 0.5991
# Iteration: 8/10, Step: 160/313, Loss: 0.8797
# Iteration: 8/10, Step: 170/313, Loss: 0.7571
# Iteration: 8/10, Step: 180/313, Loss: 1.0812
# Iteration: 8/10, Step: 190/313, Loss: 0.6685
# Iteration: 8/10, Step: 200/313, Loss: 0.7077
# Iteration: 8/10, Step: 210/313, Loss: 0.5884
# Iteration: 8/10, Step: 220/313, Loss: 0.7377
# Iteration: 8/10, Step: 230/313, Loss: 0.6420
# Iteration: 8/10, Step: 240/313, Loss: 0.6527
# Iteration: 8/10, Step: 250/313, Loss: 0.8515
# Iteration: 8/10, Step: 260/313, Loss: 0.8768
# Iteration: 8/10, Step: 270/313, Loss: 0.6205
# Iteration: 8/10, Step: 280/313, Loss: 0.4912
# Iteration: 8/10, Step: 290/313, Loss: 0.7459
# Iteration: 8/10, Step: 300/313, Loss: 0.5435
# Iteration: 8/10, Step: 310/313, Loss: 0.7575
# Iteration: 8/10, Test accuracy: 55.1579
# Iteration: 9/10, Step: 10/313, Loss: 0.8012
# Iteration: 9/10, Step: 20/313, Loss: 0.7496
# Iteration: 9/10, Step: 30/313, Loss: 0.8446
# Iteration: 9/10, Step: 40/313, Loss: 0.7055
# Iteration: 9/10, Step: 50/313, Loss: 0.5013
# Iteration: 9/10, Step: 60/313, Loss: 0.7335
# Iteration: 9/10, Step: 70/313, Loss: 0.7835
# Iteration: 9/10, Step: 80/313, Loss: 0.9444
# Iteration: 9/10, Step: 90/313, Loss: 0.4481
# Iteration: 9/10, Step: 100/313, Loss: 0.5834
# Iteration: 9/10, Step: 110/313, Loss: 0.7690
# Iteration: 9/10, Step: 120/313, Loss: 0.7888
# Iteration: 9/10, Step: 130/313, Loss: 0.7716
# Iteration: 9/10, Step: 140/313, Loss: 0.4258
# Iteration: 9/10, Step: 150/313, Loss: 0.9129
# Iteration: 9/10, Step: 160/313, Loss: 0.9804
# Iteration: 9/10, Step: 170/313, Loss: 0.5282
# Iteration: 9/10, Step: 180/313, Loss: 0.7234
# Iteration: 9/10, Step: 190/313, Loss: 0.5794
# Iteration: 9/10, Step: 200/313, Loss: 0.4904
# Iteration: 9/10, Step: 210/313, Loss: 0.5064
# Iteration: 9/10, Step: 220/313, Loss: 0.5773
# Iteration: 9/10, Step: 230/313, Loss: 0.5714
# Iteration: 9/10, Step: 240/313, Loss: 0.5522
# Iteration: 9/10, Step: 250/313, Loss: 0.6001
# Iteration: 9/10, Step: 260/313, Loss: 0.6789
# Iteration: 9/10, Step: 270/313, Loss: 0.9049
# Iteration: 9/10, Step: 280/313, Loss: 0.6224
# Iteration: 9/10, Step: 290/313, Loss: 0.8151
# Iteration: 9/10, Step: 300/313, Loss: 0.7078
# Iteration: 9/10, Step: 310/313, Loss: 0.7790
# Iteration: 9/10, Test accuracy: 59.3421
# Iteration: 10/10, Step: 10/313, Loss: 0.4886
# Iteration: 10/10, Step: 20/313, Loss: 0.8094
# Iteration: 10/10, Step: 30/313, Loss: 0.5847
# Iteration: 10/10, Step: 40/313, Loss: 0.6291
# Iteration: 10/10, Step: 50/313, Loss: 0.6840
# Iteration: 10/10, Step: 60/313, Loss: 0.4149
# Iteration: 10/10, Step: 70/313, Loss: 0.4608
# Iteration: 10/10, Step: 80/313, Loss: 0.5269
# Iteration: 10/10, Step: 90/313, Loss: 0.5048
# Iteration: 10/10, Step: 100/313, Loss: 0.6314
# Iteration: 10/10, Step: 110/313, Loss: 0.5229
# Iteration: 10/10, Step: 120/313, Loss: 0.9033
# Iteration: 10/10, Step: 130/313, Loss: 0.7599
# Iteration: 10/10, Step: 140/313, Loss: 0.5768
# Iteration: 10/10, Step: 150/313, Loss: 0.5989
# Iteration: 10/10, Step: 160/313, Loss: 0.4643
# Iteration: 10/10, Step: 170/313, Loss: 0.6093
# Iteration: 10/10, Step: 180/313, Loss: 0.6015
# Iteration: 10/10, Step: 190/313, Loss: 0.5926
# Iteration: 10/10, Step: 200/313, Loss: 0.6500
# Iteration: 10/10, Step: 210/313, Loss: 0.4258
# Iteration: 10/10, Step: 220/313, Loss: 0.7871
# Iteration: 10/10, Step: 230/313, Loss: 0.6273
# Iteration: 10/10, Step: 240/313, Loss: 0.4277
# Iteration: 10/10, Step: 250/313, Loss: 0.6712
# Iteration: 10/10, Step: 260/313, Loss: 0.6776
# Iteration: 10/10, Step: 270/313, Loss: 0.6455
# Iteration: 10/10, Step: 280/313, Loss: 0.4013
# Iteration: 10/10, Step: 290/313, Loss: 0.7727
# Iteration: 10/10, Step: 300/313, Loss: 0.5272
# Iteration: 10/10, Step: 310/313, Loss: 0.8847
# Iteration: 10/10, Test accuracy: 54.6842
# Best test accuracy: 59.3421

# %%
# !cp /content/best_model.pth /content/drive/MyDrive
